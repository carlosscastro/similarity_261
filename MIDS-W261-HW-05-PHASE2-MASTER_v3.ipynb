# %% [markdown]
# # MIDS - w261 Machine Learning At Scale
# __Course Lead:__ Dr James G. Shanahan (__email__ Jimi via  James.Shanahan _AT_ gmail.com)
#
# ## Assignment - HW5
#
#
# ---
# __Name:__  Carlos Castro
# __Class:__ MIDS w261 (Section 2, e.g., Fall 2016 Group 1)
# __Email:__  carlosscastro@iSchool.Berkeley.edu
# __Week:__   5
#
# __Due Time:__ 2 Phases.
#
# * __HW5 Phase 1__
# This can be done on a local machine (with a unit test on the cloud such as AltaScale's PaaS or on AWS) and is due Tuesday, Week 6 by 8AM (West coast time). It will primarily focus on building a unit/systems and for pairwise similarity calculations pipeline (for stripe documents)
#
# * __HW5 Phase 2__
# This will require the AltaScale cluster and will be due Tuesday, Week 7 by 8AM (West coast time).
# The focus of  HW5 Phase 2  will be to scale up the unit/systems tests to the Google 5 gram corpus. This will be a group exercise

# %%
import sys
sys.version
# Out:
# '2.7.13 | packaged by conda-forge | (default, May  2 2017, 12:48:11) \n[GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]'

# %%
pyArchive = 'hdfs:///user/nhaas/virtualenv/my_env.zip#my_env'
# !which python
# Out:
# ls: cannot access /home/nhaas/.conda/envs/py27/bin: Permission denied
# /home/chqngh/.conda/envs/py27/bin/python

# %% [markdown]
# # Table of Contents <a name="TOC"></a>
#
# 1.  [HW Instructions](#1)
# 2.  [HW References](#2)
# 3.  [HW Problems](#3)
#
#     5.4.  [HW5.4](#5.4)
#     5.5.  [HW5.5](#5.5)
#     5.6.  [HW5.6](#5.6)
#     5.7.  [HW5.7](#5.7)
#     5.8.  [HW5.8](#5.8)
#     5.9.  [HW5.9](#5.9)

# %% [markdown]
# <a name="1"></a>
# # 1 Instructions
# [Back to Table of Contents](#TOC)
#
# MIDS UC Berkeley, Machine Learning at Scale
# DATSCIW261 ASSIGNMENT #5
#
# Version 2017-9-2
#
#
# ### IMPORTANT
#
# This homework must be completed in the cloud
#
# ### === INSTRUCTIONS for SUBMISSIONS ===
# Follow the instructions for submissions carefully.
#
# Each student has a `HW-<user>` repository for all assignments.
#
# Click this link to enable you to create a github repo within the MIDS261 Classroom:
# https://classroom.github.com/assignment-invitations/3b1d6c8e58351209f9dd865537111ff8
# and follow the instructions to create a HW repo.
#
# Push the following to your HW github repo into the master branch:
# * Your local HW5 directory. Your repo file structure should look like this:
#
# ```
# HW-<user>
#     --HW3
#        |__MIDS-W261-HW-03-<Student_id>.ipynb
#        |__MIDS-W261-HW-03-<Student_id>.pdf
#        |__some other hw3 file
#     --HW4
#        |__MIDS-W261-HW-04-<Student_id>.ipynb
#        |__MIDS-W261-HW-04-<Student_id>.pdf
#        |__some other hw4 file
#     etc..
# ```

# %% [markdown]
# <a name="2">
# # 2 Useful References
# [Back to Table of Contents](#TOC)
#
# * See async and live lectures for this week

# %% [markdown]
# <a name="3">
# # 3 HW Problems
# [Back to Table of Contents](#TOC)

# %% [markdown]
# <a name="5.4"></a>
# # PHASE 2
# ----------
#
# # HW 5.4
# ## Full-scale experiment on Google N-gram data on the CLOUD
# __ Once you are happy with your test results __ proceed to generating  your results on the Google n-grams dataset.

# %% [markdown]
# ## 3.  HW5.4.0  <a name="5.4.0"></a> Run systems tests on the CLOUD  (PHASE 2)
# [Back to Table of Contents](#TOC)
#
# Repeat HW5.3.0 (using the same small data sources that were used in HW5.3.0) on ** the cloud** (e.g., AltaScale / AWS/ SoftLayer/ Azure). Make sure all tests give correct results! Good luck out there!

# %% [markdown]
# ## MapReduce Classes

# %%
# %%writefile buildStripes.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import re
import mrjob
import json
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import itertools
import collections
import logging
import time



class MRbuildStripes(MRJob):
  
    #START SUDENT CODE531_STRIPES
  
    MRJob.SORT_VALUES = True
    
    #def mapper_init(self):
    #    return self.start_time = time.time()
        
    def mapper(self, _, line):
        splits = line.rstrip("\n").split("\t")

        words = splits[0].lower().split()
        count = splits[1]

        H = {}
        for subset in itertools.combinations(sorted(set(words)), 2):
            
            # Process combinations in sorted order, i.e. "hello","tomorrow"
            if subset[0] not in H.keys():
                H[subset[0]] = {}
                H[subset[0]][subset[1]] = count 
            elif subset[1] not in H[subset[0]]:
                H[subset[0]][subset[1]] = count
            else:
                H[subset[0]][subset[1]] += count

            # Obtain combinations in reverse order, to consider them both ways
            # TODO: Should refactor this and the block above, shameless copy-paste
            if subset[1] not in H.keys():
                H[subset[1]] = {}
                H[subset[1]][subset[0]] = count 
            elif subset[0] not in H[subset[1]]:
                H[subset[1]][subset[0]] = count
            else:
                H[subset[1]][subset[0]] += count
        for key in H.keys():
            #print "%s\t%s" % (key, json.dumps(H[key]))
            yield key, H[key]

    def reducer(self, key, values):
        
        counter = {}

        for value in values:
            
            for k, v in value.iteritems():
                if k in counter:
                    counter[k] += int(v)
                else:
                    counter[k] = int(v)
        
        yield key, counter
        
    
    def steps(self):
        return [

            MRStep(#mapper_init=self.mapper_init
                   #,
                   mapper=self.mapper
                   ,
                   reducer=self.reducer
                  )
            ]
  #END SUDENT CODE531_STRIPES
  
if __name__ == '__main__':
    start_time = time.time()
    MRbuildStripes.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting buildStripes.py

# %%
# %%writefile invertedIndex.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-


from __future__ import division
import collections
import re
import json
import math
import numpy as np
import itertools
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import json
import logging
import time

class MRinvertedIndex(MRJob):
    
    #START SUDENT CODE531_INV_INDEX
  
    def mapper(self, _, line):
        key, stripeJson = line.strip().split('\t')
        key = key.strip("\"")
        stripe = json.loads(stripeJson)
        
        for k, v in stripe.iteritems():
            yield k, [key, len(stripe)]
        
    def reducer(self, key, values):

        table = {}
        for value in values:
            table[value[0]] = value[1]
            
        yield key, table
        
    #END SUDENT CODE531_INV_INDEX
        
if __name__ == '__main__':
    start_time = time.time()
    MRinvertedIndex.run() 
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting invertedIndex.py

# %%
# %%writefile similarity.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import collections
import re
import json
import math
#import numpy as np
import itertools
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import time
import logging

class MRsimilarity(MRJob):
  
    #START SUDENT CODE531_SIMILARITY

    MRJob.SORT_VALUES = True
    
    def mapper(self, _, line):
        key, valuesJson = line.strip().split('\t')
        key = key.strip("\"")
        values = json.loads(valuesJson)

        for pair in itertools.combinations(sorted(set(values)), 2):
            yield pair, [values[pair[0]], values[pair[1]]]
        
    def reducer(self, key, values):
        intersection = 0
        count1 = None
        count2 = None
        
        cosine = 0.0
        
        # Iterate through the values
        for value in values:
            # Jaccard, get counts for the intersection, and for each set
            intersection += 1
            if count1 == None:
                count1 = value[0]
                count2 = value[1]
        
            # Cosine
            a = 1 / math.sqrt(value[0])
            b = 1 / math.sqrt(value[1])
            cosine += a * b
            
        jaccard = float(intersection) / float(count1 + count2 - intersection)
        
        overlap_coefficient = float(intersection) / min(count1, count2)
        
        dice_coefficient = float(2 * intersection) / (count1 + count2)
        
        average = (cosine + jaccard + overlap_coefficient + dice_coefficient) / 4.0
        
        yield average, [key[0] + ' - ' + key[1], cosine, jaccard, overlap_coefficient, dice_coefficient]
            
    #END SUDENT CODE531_SIMILARITY
  
if __name__ == '__main__':
    start_time = time.time()
    MRsimilarity.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting similarity.py

# %% [markdown]
# ## Mini-test data

# %%
# %%writefile googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt
# A BILL FOR ESTABLISHING RELIGIOUS	59	59	54
# A Biography of General George	92	90	74
# A Case Study in Government	102	102	78
# A Case Study of Female	447	447	327
# A Case Study of Limited	55	55	43
# A Child's Christmas in Wales	1099	1061	866
# A Circumstantial Narrative of the	62	62	50
# A City by the Sea	62	60	49
# A Collection of Fairy Tales	123	117	80
# A Collection of Forms of	116	103	82
# Out:
# Overwriting googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt

# %%
# %%writefile atlas-boon-systems-test.txt
# atlas boon	50	50	50
# boon cava dipped	10	10	10
# atlas dipped	15	15	15
# Out:
# Overwriting atlas-boon-systems-test.txt

# %% [markdown]
# ## Build stripes for mini-test data

# %%
###########################################################################
# Make Stripes from ngrams for systems test 1
###########################################################################

# !hdfs dfs -rm -r systems_test_stripes_1
# !python buildStripes.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt \
    --archive={pyArchive} \
    > systems_test_stripes_1
# Out:
# rm: `systems_test_stripes_1': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/buildStripes.chqngh.20170620.045228.896373
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045228.896373/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob7031555930384798900.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0346
#   Submitted application application_1497906899862_0346
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0346/
#   Running job: job_1497906899862_0346
#   Job job_1497906899862_0346 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0346 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045228.896373/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=563
# 	File Output Format Counters
# 		Bytes Written=2406
# 	File System Counters
# 		FILE: Number of bytes read=1098
# 		FILE: Number of bytes written=401077
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1011
# 		HDFS: Number of bytes written=2406
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=23783424
# 		Total megabyte-milliseconds taken by all reduce tasks=12172800
# 		Total time spent by all map tasks (ms)=15484
# 		Total time spent by all maps in occupied slots (ms)=46452
# 		Total time spent by all reduce tasks (ms)=4755
# 		Total time spent by all reduces in occupied slots (ms)=23775
# 		Total vcore-milliseconds taken by all map tasks=15484
# 		Total vcore-milliseconds taken by all reduce tasks=4755
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3300
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=162
# 		Input split bytes=448
# 		Map input records=10
# 		Map output bytes=3359
# 		Map output materialized bytes=1076
# 		Map output records=49
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1905012736
# 		Reduce input groups=49
# 		Reduce input records=49
# 		Reduce output records=28
# 		Reduce shuffle bytes=1076
# 		Shuffled Maps =2
# 		Spilled Records=98
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7763243008
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045228.896373/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045228.896373...
# Removing temp directory /tmp/buildStripes.chqngh.20170620.045228.896373...
# WARNING:root:Elapsed time: 59.45656991 seconds
#     In minutes: 0.990942831834 mins

# %% [markdown]
# ### Stripes on Mini-Test Data Statistics:
#
# #### Time
# * _Run time: 212.87 seconds_
#
# * _Run time: 3.55 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 563_
#
# * _Bytes Written: 2046_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3900_

# %%
# !cat systems_test_stripes_1
# Out:
# "a"	{"limited": 55, "female": 447, "general": 92, "sea": 62, "in": 1201, "religious": 59, "george": 92, "biography": 92, "city": 62, "for": 59, "tales": 123, "child's": 1099, "forms": 116, "wales": 1099, "christmas": 1099, "government": 102, "collection": 239, "by": 62, "case": 604, "circumstantial": 62, "fairy": 123, "of": 895, "study": 604, "bill": 59, "establishing": 59, "narrative": 62, "the": 124}
# "bill"	{"a": 59, "religious": 59, "for": 59, "establishing": 59}
# "biography"	{"a": 92, "of": 92, "george": 92, "general": 92}
# "by"	{"a": 62, "city": 62, "the": 62, "sea": 62}
# "case"	{"a": 604, "limited": 55, "government": 102, "of": 502, "study": 604, "female": 447, "in": 102}
# "child's"	{"a": 1099, "wales": 1099, "christmas": 1099, "in": 1099}
# "christmas"	{"a": 1099, "wales": 1099, "in": 1099, "child's": 1099}
# "circumstantial"	{"a": 62, "of": 62, "the": 62, "narrative": 62}
# "city"	{"a": 62, "the": 62, "by": 62, "sea": 62}
# "collection"	{"a": 239, "forms": 116, "fairy": 123, "tales": 123, "of": 239}
# "establishing"	{"a": 59, "bill": 59, "religious": 59, "for": 59}
# "fairy"	{"a": 123, "of": 123, "tales": 123, "collection": 123}
# "female"	{"a": 447, "case": 447, "study": 447, "of": 447}
# "for"	{"a": 59, "bill": 59, "religious": 59, "establishing": 59}
# "forms"	{"a": 116, "of": 116, "collection": 116}
# "general"	{"a": 92, "of": 92, "george": 92, "biography": 92}
# "george"	{"a": 92, "of": 92, "biography": 92, "general": 92}
# "government"	{"a": 102, "case": 102, "study": 102, "in": 102}
# "in"	{"a": 1201, "case": 102, "government": 102, "study": 102, "child's": 1099, "wales": 1099, "christmas": 1099}
# "limited"	{"a": 55, "case": 55, "study": 55, "of": 55}
# "narrative"	{"a": 62, "of": 62, "the": 62, "circumstantial": 62}
# "of"	{"a": 895, "case": 502, "circumstantial": 62, "george": 92, "limited": 55, "tales": 123, "collection": 239, "the": 62, "forms": 116, "female": 447, "narrative": 62, "fairy": 123, "general": 92, "study": 502, "biography": 92}
# "religious"	{"a": 59, "bill": 59, "for": 59, "establishing": 59}
# "sea"	{"a": 62, "city": 62, "the": 62, "by": 62}
# "study"	{"a": 604, "case": 604, "limited": 55, "government": 102, "of": 502, "female": 447, "in": 102}
# "tales"	{"a": 123, "of": 123, "fairy": 123, "collection": 123}
# "the"	{"a": 124, "city": 62, "circumstantial": 62, "of": 62, "sea": 62, "narrative": 62, "by": 62}
# "wales"	{"a": 1099, "in": 1099, "christmas": 1099, "child's": 1099}

# %%
###########################################################################
# Make Stripes from ngrams for systems test 2
###########################################################################

# !hdfs dfs -rm -r systems_test_stripes_2
# !python buildStripes.py -r hadoop atlas-boon-systems-test.txt  \
    --archive={pyArchive} \
    > systems_test_stripes_2
# Out:
# rm: `systems_test_stripes_2': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/buildStripes.chqngh.20170620.045408.460027
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045408.460027/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob1428912633334101502.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0347
#   Submitted application application_1497906899862_0347
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0347/
#   Running job: job_1497906899862_0347
#   Job job_1497906899862_0347 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0347 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045408.460027/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=101
# 	File Output Format Counters
# 		Bytes Written=163
# 	File System Counters
# 		FILE: Number of bytes read=138
# 		FILE: Number of bytes written=399103
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=475
# 		HDFS: Number of bytes written=163
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=23791104
# 		Total megabyte-milliseconds taken by all reduce tasks=18296320
# 		Total time spent by all map tasks (ms)=15489
# 		Total time spent by all maps in occupied slots (ms)=46467
# 		Total time spent by all reduce tasks (ms)=7147
# 		Total time spent by all reduces in occupied slots (ms)=35735
# 		Total vcore-milliseconds taken by all map tasks=15489
# 		Total vcore-milliseconds taken by all reduce tasks=7147
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3340
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=147
# 		Input split bytes=374
# 		Map input records=3
# 		Map output bytes=217
# 		Map output materialized bytes=173
# 		Map output records=7
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1902239744
# 		Reduce input groups=7
# 		Reduce input records=7
# 		Reduce output records=4
# 		Reduce shuffle bytes=173
# 		Shuffled Maps =2
# 		Spilled Records=14
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7747014656
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045408.460027/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/buildStripes.chqngh.20170620.045408.460027...
# Removing temp directory /tmp/buildStripes.chqngh.20170620.045408.460027...
# WARNING:root:Elapsed time: 59.0218179226 seconds
#     In minutes: 0.983696965377 mins

# %% [markdown]
# ### Stripes on System Test 2 Statistics:
#
# #### Time
# * _Run time: 132.3 seconds_
#
# * _Run time: 2.2 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 138_
#
# * _Bytes Written: 98029_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3390_

# %%
# !cat systems_test_stripes_2
# Out:
# "atlas"	{"dipped": 15, "boon": 50}
# "boon"	{"atlas": 50, "dipped": 10, "cava": 10}
# "cava"	{"dipped": 10, "boon": 10}
# "dipped"	{"atlas": 15, "boon": 10, "cava": 10}

# %%
########################################################################
# Stripes for systems test 3 (given, no need to build stripes)
########################################################################

with open("systems_test_stripes_3", "w") as f:
    f.writelines([
        '"DocA"\t{"X":20, "Y":30, "Z":5}\n',
        '"DocB"\t{"X":100, "Y":20}\n',  
        '"DocC"\t{"M":5, "N":20, "Z":5, "Y":1}\n'
    ])
# !cat systems_test_stripes_3
# Out:
# "DocA"	{"X":20, "Y":30, "Z":5}
# "DocB"	{"X":100, "Y":20}
# "DocC"	{"M":5, "N":20, "Z":5, "Y":1}

# %% [markdown]
# ## Inverted indices for mini-test data

# %%
# !python invertedIndex.py -r hadoop systems_test_stripes_1 \
    --archive={pyArchive} \
    > systems_test_index_1
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/invertedIndex.chqngh.20170620.045528.664328
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045528.664328/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob1757234125207612292.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0348
#   Submitted application application_1497906899862_0348
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0348/
#   Running job: job_1497906899862_0348
#   Job job_1497906899862_0348 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0348 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045528.664328/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=3609
# 	File Output Format Counters
# 		Bytes Written=2192
# 	File System Counters
# 		FILE: Number of bytes read=1402
# 		FILE: Number of bytes written=400398
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3975
# 		HDFS: Number of bytes written=2192
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=21915648
# 		Total megabyte-milliseconds taken by all reduce tasks=10168320
# 		Total time spent by all map tasks (ms)=14268
# 		Total time spent by all maps in occupied slots (ms)=42804
# 		Total time spent by all reduce tasks (ms)=3972
# 		Total time spent by all reduces in occupied slots (ms)=19860
# 		Total vcore-milliseconds taken by all map tasks=14268
# 		Total vcore-milliseconds taken by all reduce tasks=3972
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2950
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=134
# 		Input split bytes=366
# 		Map input records=28
# 		Map output bytes=3308
# 		Map output materialized bytes=1623
# 		Map output records=158
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1898983424
# 		Reduce input groups=28
# 		Reduce input records=158
# 		Reduce output records=28
# 		Reduce shuffle bytes=1623
# 		Shuffled Maps =2
# 		Spilled Records=316
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7708123136
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045528.664328/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045528.664328...
# Removing temp directory /tmp/invertedIndex.chqngh.20170620.045528.664328...
# WARNING:root:Elapsed time: 56.6558279991 seconds
#     In minutes: 0.944263799985 mins

# %% [markdown]
# ### Inverted Indicies on Mini-Test Data Statistics:
#
# #### Time
# * _Run time: 54.2 seconds_
#
# * _Run time: 0.9 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 3609_
#
# * _Bytes Written: 2192_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2680_

# %%
# !python invertedIndex.py -r hadoop systems_test_stripes_2 \
    --archive={pyArchive} \
    > systems_test_index_2
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/invertedIndex.chqngh.20170620.045657.844880
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045657.844880/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob7157623029150331845.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0350
#   Submitted application application_1497906899862_0350
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0350/
#   Running job: job_1497906899862_0350
#   Job job_1497906899862_0350 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0350 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045657.844880/output
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=245
# 	File Output Format Counters
# 		Bytes Written=153
# 	File System Counters
# 		FILE: Number of bytes read=144
# 		FILE: Number of bytes written=397707
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=611
# 		HDFS: Number of bytes written=153
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=19974144
# 		Total megabyte-milliseconds taken by all reduce tasks=63073280
# 		Total time spent by all map tasks (ms)=13004
# 		Total time spent by all maps in occupied slots (ms)=39012
# 		Total time spent by all reduce tasks (ms)=24638
# 		Total time spent by all reduces in occupied slots (ms)=123190
# 		Total vcore-milliseconds taken by all map tasks=13004
# 		Total vcore-milliseconds taken by all reduce tasks=24638
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3770
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=188
# 		Input split bytes=366
# 		Map input records=4
# 		Map output bytes=206
# 		Map output materialized bytes=190
# 		Map output records=10
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1916178432
# 		Reduce input groups=4
# 		Reduce input records=10
# 		Reduce output records=4
# 		Reduce shuffle bytes=190
# 		Shuffled Maps =2
# 		Spilled Records=20
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7732379648
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045657.844880/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045657.844880...
# Removing temp directory /tmp/invertedIndex.chqngh.20170620.045657.844880...
# WARNING:root:Elapsed time: 128.06723094 seconds
#     In minutes: 2.134453849 mins

# %% [markdown]
# ### Inverted Indicies on System Test 2 Statistics:
#
# #### Time
# * _Run time: 62.4 seconds_
#
# * _Run time: 1.04 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 245_
#
# * _Bytes Written: 153_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3090_

# %%
# !python invertedIndex.py -r hadoop systems_test_stripes_3 \
    --archive={pyArchive} \
    > systems_test_index_3
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/invertedIndex.chqngh.20170620.045927.260016
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045927.260016/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob3298416745643758354.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0351
#   Submitted application application_1497906899862_0351
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0351/
#   Running job: job_1497906899862_0351
#   Job job_1497906899862_0351 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0351 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045927.260016/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=140
# 	File Output Format Counters
# 		Bytes Written=124
# 	File System Counters
# 		FILE: Number of bytes read=98
# 		FILE: Number of bytes written=397601
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=506
# 		HDFS: Number of bytes written=124
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=18180096
# 		Total megabyte-milliseconds taken by all reduce tasks=9154560
# 		Total time spent by all map tasks (ms)=11836
# 		Total time spent by all maps in occupied slots (ms)=35508
# 		Total time spent by all reduce tasks (ms)=3576
# 		Total time spent by all reduces in occupied slots (ms)=17880
# 		Total vcore-milliseconds taken by all map tasks=11836
# 		Total vcore-milliseconds taken by all reduce tasks=3576
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2520
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=97
# 		Input split bytes=366
# 		Map input records=3
# 		Map output bytes=144
# 		Map output materialized bytes=130
# 		Map output records=9
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1901117440
# 		Reduce input groups=5
# 		Reduce input records=9
# 		Reduce output records=5
# 		Reduce shuffle bytes=130
# 		Shuffled Maps =2
# 		Spilled Records=18
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7737995264
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045927.260016/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/invertedIndex.chqngh.20170620.045927.260016...
# Removing temp directory /tmp/invertedIndex.chqngh.20170620.045927.260016...
# WARNING:root:Elapsed time: 55.2599031925 seconds
#     In minutes: 0.920998386542 mins

# %% [markdown]
# ### Inverted Indicies on System Test 3 Statistics:
#
# #### Time
# * _Run time: 56.76 seconds_
#
# * _Run time: 0.95 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 140_
#
# * _Bytes Written: 124_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2770_

# %%
##########################################################
# Pretty print systems tests for generating Inverted Index
##########################################################
import json

for i in range(1,4):
    print "—"*100
    print "Systems test ",i," - Inverted Index"
    print "—"*100  
    with open("systems_test_index_"+str(i),"r") as f:
        lines = sorted(f.readlines())
        for line in lines:
            line = line.strip()
            word, doc_list = line.split("\t")
            doc_dict = json.loads(doc_list)
            stripe=[]
            for doc in doc_dict:
                stripe.append([doc, doc_dict[doc]])
            stripe=sorted(stripe)
            stripe.extend([["",""] for _ in xrange(3 - len(stripe))])

            print "{0:>16} |{1:>16} |{2:>16} |{3:>16}".format(
              (word), stripe[0][0]+" "+str(stripe[0][1]), stripe[1][0]+" "+str(stripe[1][1]), stripe[2][0]+" "+str(stripe[2][1]))
# Out:
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Systems test  1  - Inverted Index
# ————————————————————————————————————————————————————————————————————————————————————————————————————
#              "a" |          bill 4 |     biography 4 |            by 4
#           "bill" |            a 27 |  establishing 4 |           for 4
#      "biography" |            a 27 |       general 4 |        george 4
#             "by" |            a 27 |          city 4 |           sea 4
#           "case" |            a 27 |        female 4 |    government 4
#        "child's" |            a 27 |     christmas 4 |            in 7
#      "christmas" |            a 27 |       child's 4 |            in 7
# "circumstantial" |            a 27 |     narrative 4 |           of 15
#           "city" |            a 27 |            by 4 |           sea 4
#     "collection" |            a 27 |         fairy 4 |         forms 3
#   "establishing" |            a 27 |          bill 4 |           for 4
#          "fairy" |            a 27 |    collection 5 |           of 15
#         "female" |            a 27 |          case 7 |           of 15
#            "for" |            a 27 |          bill 4 |  establishing 4
#          "forms" |            a 27 |    collection 5 |           of 15
#        "general" |            a 27 |     biography 4 |        george 4
#         "george" |            a 27 |     biography 4 |       general 4
#     "government" |            a 27 |          case 7 |            in 7
#             "in" |            a 27 |          case 7 |       child's 4
#        "limited" |            a 27 |          case 7 |           of 15
#      "narrative" |            a 27 |circumstantial 4 |           of 15
#             "of" |            a 27 |     biography 4 |          case 7
#      "religious" |            a 27 |          bill 4 |  establishing 4
#            "sea" |            a 27 |            by 4 |          city 4
#          "study" |            a 27 |          case 7 |        female 4
#          "tales" |            a 27 |    collection 5 |         fairy 4
#            "the" |            a 27 |            by 4 |circumstantial 4
#          "wales" |            a 27 |       child's 4 |     christmas 4
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Systems test  2  - Inverted Index
# ————————————————————————————————————————————————————————————————————————————————————————————————————
#          "atlas" |          boon 3 |        dipped 3 |
#           "boon" |         atlas 2 |          cava 2 |        dipped 3
#           "cava" |          boon 3 |        dipped 3 |
#         "dipped" |         atlas 2 |          boon 3 |          cava 2
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# Systems test  3  - Inverted Index
# ————————————————————————————————————————————————————————————————————————————————————————————————————
#              "M" |          DocC 4 |                 |
#              "N" |          DocC 4 |                 |
#              "X" |          DocA 3 |          DocB 2 |
#              "Y" |          DocA 3 |          DocB 2 |          DocC 4
#              "Z" |          DocA 3 |          DocC 4 |

# %% [markdown]
# ## Similarities for mini-test data

# %%
# !python similarity.py -r hadoop systems_test_index_1 \
    --archive={pyArchive} \
    > systems_test_similarities_1
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/similarity.chqngh.20170620.050037.585331
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050037.585331/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob2623619550988368011.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0353
#   Submitted application application_1497906899862_0353
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0353/
#   Running job: job_1497906899862_0353
#   Job job_1497906899862_0353 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0353 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050037.585331/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=3288
# 	File Output Format Counters
# 		Bytes Written=35050
# 	File System Counters
# 		FILE: Number of bytes read=3756
# 		FILE: Number of bytes written=407377
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3642
# 		HDFS: Number of bytes written=35050
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=17995776
# 		Total megabyte-milliseconds taken by all reduce tasks=9062400
# 		Total time spent by all map tasks (ms)=11716
# 		Total time spent by all maps in occupied slots (ms)=35148
# 		Total time spent by all reduce tasks (ms)=3540
# 		Total time spent by all reduces in occupied slots (ms)=17700
# 		Total vcore-milliseconds taken by all map tasks=11716
# 		Total vcore-milliseconds taken by all reduce tasks=3540
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2600
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=64
# 		Input split bytes=354
# 		Map input records=28
# 		Map output bytes=19239
# 		Map output materialized bytes=4940
# 		Map output records=673
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1898356736
# 		Reduce input groups=378
# 		Reduce input records=673
# 		Reduce output records=378
# 		Reduce shuffle bytes=4940
# 		Shuffled Maps =2
# 		Spilled Records=1346
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7719829504
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050037.585331/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050037.585331...
# Removing temp directory /tmp/similarity.chqngh.20170620.050037.585331...
# WARNING:root:Elapsed time: 54.8930828571 seconds
#     In minutes: 0.914884714286 mins

# %% [markdown]
# ### Similarities on Mini Test Data Statistics:
#
# #### Time
# * _Run time: 57.32 seconds_
#
# * _Run time: 0.95 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 3288_
#
# * _Bytes Written: 35050_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2590_

# %%
# !python similarity.py -r hadoop systems_test_index_2 \
    --archive={pyArchive} \
    > systems_test_similarities_2
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/similarity.chqngh.20170620.050132.718088
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050132.718088/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob92714044526091487.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0354
#   Submitted application application_1497906899862_0354
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0354/
#   Running job: job_1497906899862_0354
#   Job job_1497906899862_0354 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0354 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050132.718088/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=230
# 	File Output Format Counters
# 		Bytes Written=511
# 	File System Counters
# 		FILE: Number of bytes read=130
# 		FILE: Number of bytes written=398996
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=584
# 		HDFS: Number of bytes written=511
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=17571840
# 		Total megabyte-milliseconds taken by all reduce tasks=14699520
# 		Total time spent by all map tasks (ms)=11440
# 		Total time spent by all maps in occupied slots (ms)=34320
# 		Total time spent by all reduce tasks (ms)=5742
# 		Total time spent by all reduces in occupied slots (ms)=28710
# 		Total vcore-milliseconds taken by all map tasks=11440
# 		Total vcore-milliseconds taken by all reduce tasks=5742
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2430
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=87
# 		Input split bytes=354
# 		Map input records=4
# 		Map output bytes=212
# 		Map output materialized bytes=191
# 		Map output records=8
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1895505920
# 		Reduce input groups=6
# 		Reduce input records=8
# 		Reduce output records=6
# 		Reduce shuffle bytes=191
# 		Shuffled Maps =2
# 		Spilled Records=16
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7708872704
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050132.718088/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050132.718088...
# Removing temp directory /tmp/similarity.chqngh.20170620.050132.718088...
# WARNING:root:Elapsed time: 54.8316318989 seconds
#     In minutes: 0.913860531648 mins

# %% [markdown]
# ### Similarities on Systems Test 2 Statistics:
#
# #### Time
# * _Run time: 57.91 seconds_
#
# * _Run time: 0.97 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 230_
#
# * _Bytes Written: 51_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2740_

# %%
# !python similarity.py -r hadoop systems_test_index_3 \
    --archive={pyArchive} \
    > systems_test_similarities_3
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/similarity.chqngh.20170620.050227.796134
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050227.796134/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob394788616189327589.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0355
#   Submitted application application_1497906899862_0355
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0355/
#   Running job: job_1497906899862_0355
#   Job job_1497906899862_0355 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0355 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050227.796134/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=186
# 	File Output Format Counters
# 		Bytes Written=327
# 	File System Counters
# 		FILE: Number of bytes read=80
# 		FILE: Number of bytes written=398869
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=540
# 		HDFS: Number of bytes written=327
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=17966592
# 		Total megabyte-milliseconds taken by all reduce tasks=14824960
# 		Total time spent by all map tasks (ms)=11697
# 		Total time spent by all maps in occupied slots (ms)=35091
# 		Total time spent by all reduce tasks (ms)=5791
# 		Total time spent by all reduces in occupied slots (ms)=28955
# 		Total vcore-milliseconds taken by all map tasks=11697
# 		Total vcore-milliseconds taken by all reduce tasks=5791
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2400
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=84
# 		Input split bytes=354
# 		Map input records=5
# 		Map output bytes=125
# 		Map output materialized bytes=111
# 		Map output records=5
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1909940224
# 		Reduce input groups=3
# 		Reduce input records=5
# 		Reduce output records=3
# 		Reduce shuffle bytes=111
# 		Shuffled Maps =2
# 		Spilled Records=10
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7748796416
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050227.796134/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/similarity.chqngh.20170620.050227.796134...
# Removing temp directory /tmp/similarity.chqngh.20170620.050227.796134...
# WARNING:root:Elapsed time: 56.9997999668 seconds
#     In minutes: 0.949996666114 mins

# %% [markdown]
# ### Similarities on Systems Test 3 Statistics:
#
# #### Time
# * _Run time: 59.13 seconds_
#
# * _Run time: 0.99 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 186_
#
# * _Bytes Written: 327_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3420_

# %%
############################################
# Pretty print systems tests
############################################

import json
for i in range(1,4):
  print '—'*110
  print "Systems test ",i," - Similarity measures"
  print '—'*110
  print "{0:>15} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
          "average", "pair", "cosine", "jaccard", "overlap", "dice")
  print '-'*110

  with open("systems_test_similarities_"+str(i),"r") as f:
      lines = f.readlines()
      for line in lines:
          line = line.strip()
          avg,stripe = line.split("\t")
          stripe = json.loads(stripe)

          print "{0:>15f} |{1:>15} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
              float(avg), stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]))
# Out:
# ——————————————————————————————————————————————————————————————————————————————————————————————————————————————
# Systems test  1  - Similarity measures
# ——————————————————————————————————————————————————————————————————————————————————————————————————————————————
#         average |           pair |         cosine |        jaccard |        overlap |           dice
# --------------------------------------------------------------------------------------------------------------
#        0.334842 |       a - bill |       0.288675 |       0.107143 |       0.750000 |       0.193548
#        0.334842 |  a - biography |       0.288675 |       0.107143 |       0.750000 |       0.193548
#        0.334842 |         a - by |       0.288675 |       0.107143 |       0.750000 |       0.193548
#        0.465201 |       a - case |       0.436436 |       0.214286 |       0.857143 |       0.352941
#        0.334842 |    a - child's |       0.288675 |       0.107143 |       0.750000 |       0.193548
#        0.334842 
       0.377964 |       0.222222 |       0.500000 |       0.363636
#        0.255952 |    study - the |       0.285714 |       0.166667 |       0.285714 |       0.285714
#        0.365956 |  study - wales |       0.377964 |       0.222222 |       0.500000 |       0.363636
#        0.365956 |    tales - the |       0.377964 |       0.222222 |       0.500000 |       0.363636
#        0.223214 |  tales - wales |       0.250000 |       0.142857 |       0.250000 |       0.250000
#        0.180200 |    the - wales |       0.188982 |       0.100000 |       0.250000 |       0.181818
# ——————————————————————————————————————————————————————————————————————————————————————————————————————————————
# Systems test  2  - Similarity measures
# ——————————————————————————————————————————————————————————————————————————————————————————————————————————————
#         average |           pair |         cosine |        jaccard |        overlap |           dice
# --------------------------------------------------------------------------------------------------------------
#        0.389562 |   atlas - boon |       0.408248 |       0.250000 |       0.500000 |       0.400000
#        1.000000 |   atlas - cava |       1.000000 |       1.000000 |       1.000000 |       1.000000
#        0.389562 | atlas - dipped |       0.408248 |       0.250000 |       0.500000 |       0.400000
#        0.389562 |    boon - cava |       0.408248 |       0.250000 |       0.500000 |       0.400000
#        0.625000 |  boon - dipped |       0.666667 |       0.500000 |       0.666667 |       0.666667
#        0.389562 |  cava - dipped |       0.408248 |       0.250000 |       0.500000 |       0.400000
# ——————————————————————————————————————————————————————————————————————————————————————————————————————————————
# Systems test  3  - Similarity measures
# ——————————————————————————————————————————————————————————————————————————————————————————————————————————————
#         average |           pair |         cosine |        jaccard |        overlap |           dice
# --------------------------------------------------------------------------------------------------------------
#        0.820791 |    DocA - DocB |       0.816497 |       0.666667 |       1.000000 |       0.800000
#        0.553861 |    DocA - DocC |       0.577350 |       0.400000 |       0.666667 |       0.571429
#        0.346722 |    DocB - DocC |       0.353553 |       0.200000 |       0.500000 |       0.333333

# %% [markdown]
# ## 3.  HW5.4.1 <a name="5.4.1"></a>Full-scale experiment: EDA of Google n-grams dataset (PHASE 2)
# [Back to Table of Contents](#TOC)
#
# Do some EDA on this dataset using mrjob, e.g.,
#
# - A. Longest 5-gram (number of characters)
# - B. Top 10 most frequent words (please use the count information), i.e., unigrams
# - C. 20 Most/Least densely appearing words (count/pages_count) sorted in decreasing order of relative frequency
# - D. Distribution of 5-gram sizes (character length).  E.g., count (using the count field) up how many times a 5-gram of 50 characters shows up. Plot the data graphically using a histogram.

# %% [markdown]
# ### HW5.4.1 - A. Longest 5-gram (number of characters)

# %%
# %%writefile longest5gram.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import re

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import logging
import time

class longest5gram(MRJob):
    
    # START STUDENT CODE 5.4.1.A
    
    MRJob.SORT_VALUES = True

    def __init__(self, args):
        super(longest5gram, self).__init__(args)
        self.max_count = 0
        self.max_grams = []
        
    def mapper(self, _, line):
        
        # Split line
        splits = line.rstrip("\n").split("\t")
        words = splits[0].lower().split()
        
        char_count = 0
        
        # Count characters
        for word in words:
            char_count += len(word)
        
        # Optimization: we track the max count local to the current mapper instance. If records
        # have higher count than the max, we output them and update the max. We don't yield
        # records that are smaller than the local max. 
        # Even some non-max records are passed on, the good thing about this is that it is extremely memory efficient
        # in that it uses constant memory.
        if char_count > self.max_count:
            self.max_count = char_count
            yield (words), char_count
        elif char_count == self.max_count:
            yield (words), char_count
            
    
    def combiner(self, ngram, char_counts):
        current_max = max(char_counts)
        
        # Optimization: we track the max count local to the current combiner instance. If records
        # have higher count than the max, we output them and update the max. We don't yield
        # records that are smaller than the local max, drastically reducing work on shuffling and sorting
        # Even some non-max or local max records are passed on, the good thing about this is that it is extremely 
        # memory efficient in that it uses constant memory (just 1 integer :)
        if current_max > self.max_count:
            self.max_count = current_max
            yield ngram, current_max
        elif current_max == self.max_count:
            yield ngram, current_max
    
    def reducer(self, ngram, char_counts):
            
        current_count = max(char_counts)

        # Track in max_grams the n-grams with the max count of words
        if current_count > self.max_count:
            self.max_count = current_count
            self.max_grams = [(current_count, ngram)]
        elif current_count == self.max_count:
            self.max_grams.append((current_count, ngram))

    def reducer_final(self):
        # Once
        for gram in self.max_grams:
            yield gram[0], gram[1]


    def steps(self):
        
        # We need 1 reducer for this approach. However the optimizations in the mappers and combiners
        # help us ensure that a small percentage of records get to the reducer
        custom_jobconf = {
            'stream.num.map.output.key.fields':'1',
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-k2,2nr',
            'mapred.reduce.tasks': '1'
        }

        return [
                MRStep(jobconf=custom_jobconf,
                    mapper=self.mapper,
                    reducer=self.reducer,
                    combiner = self.combiner,
                    reducer_final = self.reducer_final
                      )
                 ]

    # END STUDENT CODE 5.4.1.A

if __name__ == '__main__':
    start_time = time.time()
    longest5gram.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting longest5gram.py

# %% [markdown]
# __On test data set:__

# %%
# !hdfs dfs -rm -r systems_test_stripes_5.4.1.a_1
# !python longest5gram.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt \
    --archive={pyArchive} \
    > systems_test_stripes_5.4.1.a_1
# Out:
# rm: `systems_test_stripes_5.4.1.a_1': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/longest5gram.chqngh.20170620.050440.591520
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050440.591520/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob6376814382472075240.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0356
#   Submitted application application_1497906899862_0356
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0356/
#   Running job: job_1497906899862_0356
#   Job job_1497906899862_0356 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0356 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050440.591520/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=563
# 	File Output Format Counters
# 		Bytes Written=106
# 	File System Counters
# 		FILE: Number of bytes read=160
# 		FILE: Number of bytes written=401456
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1011
# 		HDFS: Number of bytes written=106
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=18796032
# 		Total megabyte-milliseconds taken by all reduce tasks=15656960
# 		Total time spent by all map tasks (ms)=12237
# 		Total time spent by all maps in occupied slots (ms)=36711
# 		Total time spent by all reduce tasks (ms)=6116
# 		Total time spent by all reduces in occupied slots (ms)=30580
# 		Total vcore-milliseconds taken by all map tasks=12237
# 		Total vcore-milliseconds taken by all reduce tasks=6116
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2720
# 		Combine input records=3
# 		Combine output records=3
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=99
# 		Input split bytes=448
# 		Map input records=10
# 		Map output bytes=154
# 		Map output materialized bytes=176
# 		Map output records=3
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1893728256
# 		Reduce input groups=3
# 		Reduce input records=3
# 		Reduce output records=2
# 		Reduce shuffle bytes=176
# 		Shuffled Maps =2
# 		Spilled Records=6
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7744573440
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050440.591520/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050440.591520...
# Removing temp directory /tmp/longest5gram.chqngh.20170620.050440.591520...
# WARNING:root:Elapsed time: 58.3703050613 seconds
#     In minutes: 0.972838417689 mins

# %% [markdown]
# ### Longest 5 Gram on Mini Test Set Statistics:
#
# #### Time
# * _Run time: 518.49 seconds_
#
# * _Run time: 8.64 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 563_
#
# * _Bytes Written: 106_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3530_

# %%
# !cat systems_test_stripes_5.4.1.a_1
# Out:
# 29	["a", "bill", "for", "establishing", "religious"]
# 29	["a", "circumstantial", "narrative", "of", "the"]

# %% [markdown]
# __On full data set:__

# %%
# !hdfs dfs -rm -r full_stripes_5.4.1.a
# !python longest5gram.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ \
    --archive={pyArchive} \
    > full_stripes_5.4.1.a
# Out:
# rm: `full_stripes_5.4.1.a': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/longest5gram.chqngh.20170620.050541.695418
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050541.695418/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob8470097480714257355.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 190
#   number of splits:190
#   Submitting tokens for job: job_1497906899862_0357
#   Submitted application application_1497906899862_0357
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0357/
#   Running job: job_1497906899862_0357
#   Job job_1497906899862_0357 running in uber mode : false
#    map 0% reduce 0%
#    map 2% reduce 0%
#    map 5% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 16% reduce 0%
#    map 18% reduce 0%
#    map 20% reduce 0%
#    map 23% reduce 0%
#    map 26% reduce 0%
#    map 28% reduce 0%
#    map 31% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 41% reduce 0%
#    map 47% reduce 0%
#    map 52% reduce 0%
#    map 59% reduce 0%
#    map 62% reduce 0%
#    map 65% reduce 0%
#    map 67% reduce 0%
#    map 70% reduce 0%
#    map 72% reduce 0%
#    map 75% reduce 0%
#    map 76% reduce 0%
#    map 77% reduce 0%
#    map 80% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 83% reduce 0%
#    map 84% reduce 0%
#    map 85% reduce 0%
#    map 86% reduce 0%
#    map 87% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 93% reduce 0%
#    map 95% reduce 0%
#    map 97% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0357 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050541.695418/output
# Counters: 51
# 	File Input Format Counters
# 		Bytes Read=2156069116
# 	File Output Format Counters
# 		Bytes Written=360
# 	File System Counters
# 		FILE: Number of bytes read=37741
# 		FILE: Number of bytes written=25623012
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2156101116
# 		HDFS: Number of bytes written=360
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=573
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=2
# 		Launched map tasks=192
# 		Launched reduce tasks=1
# 		Other local map tasks=2
# 		Rack-local map tasks=190
# 		Total megabyte-milliseconds taken by all map tasks=8733817344
# 		Total megabyte-milliseconds taken by all reduce tasks=69972480
# 		Total time spent by all map tasks (ms)=5686079
# 		Total time spent by all maps in occupied slots (ms)=17058237
# 		Total time spent by all reduce tasks (ms)=27333
# 		Total time spent by all reduces in occupied slots (ms)=136665
# 		Total vcore-milliseconds taken by all map tasks=5686079
# 		Total vcore-milliseconds taken by all reduce tasks=27333
# 	Map-Reduce Framework
# 		CPU time spent (ms)=633030
# 		Combine input records=2699
# 		Combine output records=1108
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=38548
# 		Input split bytes=32000
# 		Map input records=58682266
# 		Map output bytes=172790
# 		Map output materialized bytes=63827
# 		Map output records=2699
# 		Merged Map outputs=190
# 		Physical memory (bytes) snapshot=154096226304
# 		Reduce input groups=1108
# 		Reduce input records=1108
# 		Reduce output records=2
# 		Reduce shuffle bytes=63827
# 		Shuffled Maps =190
# 		Spilled Records=2216
# 		Total committed heap usage (bytes)=299931533312
# 		Virtual memory (bytes) snapshot=421313400832
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050541.695418/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/longest5gram.chqngh.20170620.050541.695418...
# Removing temp directory /tmp/longest5gram.chqngh.20170620.050541.695418...
# WARNING:root:Elapsed time: 139.780970812 seconds
#     In minutes: 2.32968284686 mins

# %% [markdown]
# ### Longest 5 Gram on Full Set Statistics:
#
# #### Time
# * _Run time: 152.98 seconds_
#
# * _Run time: 2.55 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 2156069116_
#
# * _Bytes Written: 360_
#
# #### Cluster Resources
# * _Number of Mappers: 191_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 530340_

# %%
# !cat full_stripes_5.4.1.a
# Out:
# 155	["roplezimpredastrodonbraslpklson", "yhroaclmparcheyxmmioudavesaurus", "piofpilocowersuruasogetsesnegcp", "tyravopsifengoquapialloboskenuo", "owinfuyaiokenecksasxhyilpoynuat"]
# 155	["aiopjumrxuyvaslyhypsibemapodikr", "ufrydiuuolbigasuaurusrexlisnaye", "rnoondqsrunsubunougrabberyairtc", "utahraptoredileipmilbdummyuveri", "syevrahvelocyallosauruslinrotsr"]

# %% [markdown]
# ## Report Stats:
# ## example:
# ## Longest 5grams MR stats
#
#     ec2_instance_type: m3.xlarge
#     num_ec2_instances: 15
#
# __Step 1:__
#
#     RUNNING for 107.0s ~= 2 minutes
#     Reduce tasks = 16
#
# __Step 2:__
#
#     RUNNING for 108.8s ~= 2 minutes
#     Reduce tasks = 1

# %% [markdown]
# ### HW5.4.1 - B. Top 10 most frequent words

# %%
# %%writefile mostFrequentWords.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import re

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import logging
import time

class mostFrequentWords(MRJob):

    # START STUDENT CODE 5.4.1.B
            
    MRJob.SORT_VALUES = True
        
    def mapper(self, _, line):
        
        # Split line
        splits = line.rstrip("\n").split("\t")
        words = splits[0].lower().split()
        count = int(splits[1])
        
        for word in words:
            yield word, count
            
    
    def combiner(self, word, counts):
        total = sum(count for count in counts)
        yield word, total
    
    def reducer(self, word, counts):
        total = sum(count for count in counts)
        yield total, word
    
    def max_reducer(self, count, words):
        for word in words:
            yield word, count

    def steps(self):
        
        custom_jobconf = {
            'stream.num.map.output.key.fields':'2',
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-k1,1nr',
            'mapred.reduce.tasks': '1'
        }

        return [
                MRStep(mapper=self.mapper,
                    reducer=self.reducer,
                    combiner = self.combiner),
                MRStep(jobconf=custom_jobconf,
                       reducer=self.max_reducer)
                 ]

    # END STUDENT CODE 5.4.1.B
        
if __name__ == '__main__':
    start_time = time.time()
    mostFrequentWords.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting mostFrequentWords.py

# %% [markdown]
# __On the test data set:__

# %%
# !hdfs dfs -rm -r systems_test_stripes_5.4.1.b_1
# !python mostFrequentWords.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt \
    --archive={pyArchive} \
    > systems_test_stripes_5.4.1.b_1
# Out:
# rm: `systems_test_stripes_5.4.1.b_1': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/mostFrequentWords.chqngh.20170620.050831.478210
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.050831.478210/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob4245309627118927000.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0359
#   Submitted application application_1497906899862_0359
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0359/
#   Running job: job_1497906899862_0359
#   Job job_1497906899862_0359 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0359 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.050831.478210/step-output/0000
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=563
# 	File Output Format Counters
# 		Bytes Written=357
# 	File System Counters
# 		FILE: Number of bytes read=430
# 		FILE: Number of bytes written=401198
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1021
# 		HDFS: Number of bytes written=357
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=51747840
# 		Total megabyte-milliseconds taken by all reduce tasks=37637120
# 		Total time spent by all map tasks (ms)=33690
# 		Total time spent by all maps in occupied slots (ms)=101070
# 		Total time spent by all reduce tasks (ms)=14702
# 		Total time spent by all reduces in occupied slots (ms)=73510
# 		Total vcore-milliseconds taken by all map tasks=33690
# 		Total vcore-milliseconds taken by all reduce tasks=14702
# 	Map-Reduce Framework
# 		CPU time spent (ms)=4700
# 		Combine input records=50
# 		Combine output records=31
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=142
# 		Input split bytes=458
# 		Map input records=10
# 		Map output bytes=602
# 		Map output materialized bytes=458
# 		Map output records=50
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1922347008
# 		Reduce input groups=28
# 		Reduce input records=31
# 		Reduce output records=28
# 		Reduce shuffle bytes=458
# 		Shuffled Maps =2
# 		Spilled Records=62
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7708274688
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob2530887504536542504.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0361
#   Submitted application application_1497906899862_0361
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0361/
#   Running job: job_1497906899862_0361
#   Job job_1497906899862_0361 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0361 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.050831.478210/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=536
# 	File Output Format Counters
# 		Bytes Written=357
# 	File System Counters
# 		FILE: Number of bytes read=396
# 		FILE: Number of bytes written=400663
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=908
# 		HDFS: Number of bytes written=357
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=18137088
# 		Total megabyte-milliseconds taken by all reduce tasks=15034880
# 		Total time spent by all map tasks (ms)=11808
# 		Total time spent by all maps in occupied slots (ms)=35424
# 		Total time spent by all reduce tasks (ms)=5873
# 		Total time spent by all reduces in occupied slots (ms)=29365
# 		Total vcore-milliseconds taken by all map tasks=11808
# 		Total vcore-milliseconds taken by all reduce tasks=5873
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2460
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=82
# 		Input split bytes=372
# 		Map input records=28
# 		Map output bytes=385
# 		Map output materialized bytes=437
# 		Map output records=28
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1904222208
# 		Reduce input groups=28
# 		Reduce input records=28
# 		Reduce output records=28
# 		Reduce shuffle bytes=437
# 		Shuffled Maps =2
# 		Spilled Records=56
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7759396864
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.050831.478210/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.050831.478210...
# Removing temp directory /tmp/mostFrequentWords.chqngh.20170620.050831.478210...
# WARNING:root:Elapsed time: 139.109462976 seconds
#     In minutes: 2.31849104961 mins

# %% [markdown]
# ### Most Frequent Words on Test Set Statistics:
#
# #### Time
# * _Run time: 92.93 seconds_
#
# * _Run time: 1.55 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 536_
#
# * _Bytes Written: 357_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2400_

# %%
# !head -5 systems_test_stripes_5.4.1.b_1
# Out:
# "a"	2217
# "in"	1201
# "wales"	1099
# "christmas"	1099
# "child's"	1099

# %% [markdown]
# __On the full data set:__

# %%
# !hdfs dfs -rm -r full_mostFrequentWords_5.4.1.b
# !python mostFrequentWords.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ \
    --archive={pyArchive} \
    > full_mostFrequentWords_5.4.1.b
# Out:
# rm: `full_mostFrequentWords_5.4.1.b': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/mostFrequentWords.chqngh.20170620.051053.329505
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.051053.329505/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob4103395024159523718.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 190
#   number of splits:190
#   Submitting tokens for job: job_1497906899862_0362
#   Submitted application application_1497906899862_0362
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0362/
#   Running job: job_1497906899862_0362
#   Job job_1497906899862_0362 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 16% reduce 0%
#    map 17% reduce 0%
#    map 18% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 40% reduce 0%
#    map 41% reduce 0%
#    map 42% reduce 0%
#    map 43% reduce 0%
#    map 44% reduce 0%
#    map 45% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 69% reduce 0%
#    map 70% reduce 0%
#    map 71% reduce 0%
#    map 73% reduce 0%
#    map 75% reduce 0%
#    map 76% reduce 0%
#    map 77% reduce 0%
#    map 78% reduce 0%
#    map 79% reduce 0%
#    map 80% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 83% reduce 0%
#    map 84% reduce 0%
#    map 85% reduce 0%
#    map 86% reduce 0%
#    map 87% reduce 0%
#    map 88% reduce 0%
#    map 89% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 67%
#    map 100% reduce 68%
#    map 100% reduce 69%
#    map 100% reduce 70%
#    map 100% reduce 71%
#    map 100% reduce 72%
#    map 100% reduce 73%
#    map 100% reduce 74%
#    map 100% reduce 75%
#    map 100% reduce 76%
#    map 100% reduce 77%
#    map 100% reduce 78%
#    map 100% reduce 79%
#    map 100% reduce 80%
#    map 100% reduce 81%
#    map 100% reduce 82%
#    map 100% reduce 83%
#    map 100% reduce 84%
#    map 100% reduce 85%
#    map 100% reduce 86%
#    map 100% reduce 87%
#    map 100% reduce 88%
#    map 100% reduce 89%
#    map 100% reduce 90%
#    map 100% reduce 91%
#    map 100% reduce 92%
#    map 100% reduce 93%
#    map 100% reduce 94%
#    map 100% reduce 95%
#    map 100% reduce 96%
#    map 100% reduce 97%
#    map 100% reduce 98%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497906899862_0362 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.051053.329505/step-output/0000
# Counters: 51
# 	File Input Format Counters
# 		Bytes Read=2156069116
# 	File Output Format Counters
# 		Bytes Written=4158739
# 	File System Counters
# 		FILE: Number of bytes read=39014765
# 		FILE: Number of bytes written=138285192
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2156101116
# 		HDFS: Number of bytes written=4158739
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=573
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=191
# 		Launched reduce tasks=1
# 		Other local map tasks=2
# 		Rack-local map tasks=189
# 		Total megabyte-milliseconds taken by all map tasks=42269016576
# 		Total megabyte-milliseconds taken by all reduce tasks=321149440
# 		Total time spent by all map tasks (ms)=27518891
# 		Total time spent by all maps in occupied slots (ms)=82556673
# 		Total time spent by all reduce tasks (ms)=125449
# 		Total time spent by all reduces in occupied slots (ms)=627245
# 		Total vcore-milliseconds taken by all map tasks=27518891
# 		Total vcore-milliseconds taken by all reduce tasks=125449
# 	Map-Reduce Framework
# 		CPU time spent (ms)=15240570
# 		Combine input records=293411330
# 		Combine output records=6822745
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=114953
# 		Input split bytes=32000
# 		Map input records=58682266
# 		Map output bytes=3430141090
# 		Map output materialized bytes=73800744
# 		Map output records=293411330
# 		Merged Map outputs=190
# 		Physical memory (bytes) snapshot=154772475904
# 		Reduce input groups=269339
# 		Reduce input records=6822745
# 		Reduce output records=269339
# 		Reduce shuffle bytes=73800744
# 		Shuffled Maps =190
# 		Spilled Records=13645490
# 		Total committed heap usage (bytes)=298140041216
# 		Virtual memory (bytes) snapshot=421148364800
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob7553425776274955891.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0364
#   Submitted application application_1497906899862_0364
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0364/
#   Running job: job_1497906899862_0364
#   Job job_1497906899862_0364 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 88%
#    map 100% reduce 100%
#   Job job_1497906899862_0364 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.051053.329505/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=4176522
# 	File Output Format Counters
# 		Bytes Written=4158739
# 	File System Counters
# 		FILE: Number of bytes read=2953963
# 		FILE: Number of bytes written=6323053
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=4176894
# 		HDFS: Number of bytes written=4158739
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=19928064
# 		Total megabyte-milliseconds taken by all reduce tasks=35955200
# 		Total time spent by all map tasks (ms)=12974
# 		Total time spent by all maps in occupied slots (ms)=38922
# 		Total time spent by all reduce tasks (ms)=14045
# 		Total time spent by all reduces in occupied slots (ms)=70225
# 		Total vcore-milliseconds taken by all map tasks=12974
# 		Total vcore-milliseconds taken by all reduce tasks=14045
# 	Map-Reduce Framework
# 		CPU time spent (ms)=13250
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=191
# 		Input split bytes=372
# 		Map input records=269339
# 		Map output bytes=4428078
# 		Map output materialized bytes=2969260
# 		Map output records=269339
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1944502272
# 		Reduce input groups=269339
# 		Reduce input records=269339
# 		Reduce output records=269339
# 		Reduce shuffle bytes=2969260
# 		Shuffled Maps =2
# 		Spilled Records=538678
# 		Total committed heap usage (bytes)=5280104448
# 		Virtual memory (bytes) snapshot=7745040384
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.051053.329505/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/mostFrequentWords.chqngh.20170620.051053.329505...
# Removing temp directory /tmp/mostFrequentWords.chqngh.20170620.051053.329505...
# WARNING:root:Elapsed time: 461.545595884 seconds
#     In minutes: 7.69242659807 mins

# %% [markdown]
# ### Most Frequent Words on Full Set Statistics:
#
# #### Time
# * _Run time: 479.48 seconds_
#
# * _Run time: 7.99 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 4176522_
#
# * _Bytes Written: 4158739_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 13650_

# %%
# !head -5 full_mostFrequentWords_5.4.1.b
# Out:
# "the"	5490815394
# "of"	3698583299
# "to"	2227866570
# "in"	1421312776
# "a"	1361123022

# %% [markdown]
# ## Most frequent words MR stats
#
#     ec2_instance_type: m3.xlarge
#     num_ec2_instances: 15
#
# __Step 1:__
#
#     RUNNING for 590.7s ~= 10 minutes
#     Launched map tasks=191
#     Launched reduce tasks=57
#
# __Step 2:__
#
#     RUNNING for 76.6s
#     Launched map tasks=110
#     Launched reduce tasks=16

# %% [markdown]
# ### HW5.4.1 - C. 20 Most/Least densely appearing words

# %%
# %%writefile mostLeastDenseWords.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-
from __future__ import division
import re
import numpy as np
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import time
import logging
import math

class mostLeastDenseWords(MRJob):
    
    # START STUDENT CODE 5.4.1.C
           
    MRJob.SORT_VALUES = True
        
    def __init__(self, args):
        super(mostLeastDenseWords, self).__init__(args)
        self.total_word_count = None
        
    def mapper(self, _, line):
        
        # Split line
        splits = line.rstrip("\n").split("\t")
        words = splits[0].lower().split()
        count = int(splits[1])
        
        for word in words:
            yield "*", count
            yield word, count
            
    
    def combiner(self, word, counts):
        total = sum(count for count in counts)
        yield word, total
    
    def reducer(self, word, counts):
    
        total = sum(count for count in counts)
        
        if word == "*":
            self.total_word_count = total
        else:
            yield math.log(float(total) / float(self.total_word_count)), word
    
    def max_reducer(self, count, words):
        for word in words:
            yield word, count

    def steps(self):
        
        custom_jobconf = {
            'stream.num.map.output.key.fields':'2',
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-g -k1,1nr',
            'mapred.reduce.tasks': '1'
        }

        return [
                MRStep(
                    mapper=self.mapper,
                    reducer=self.reducer,
                    combiner = self.combiner),
                MRStep(jobconf=custom_jobconf,
                       reducer=self.max_reducer)
                 ]
    
    # END STUDENT CODE 5.4.1.C
        
if __name__ == '__main__':
    start_time = time.time()
    mostLeastDenseWords.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting mostLeastDenseWords.py

# %% [markdown]
# __On the test data set:__

# %%
# !hdfs dfs -rm -r systems_test_stripes_5.4.1.c_1
# !python mostLeastDenseWords.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt \
    --archive={pyArchive} \
    > systems_test_stripes_5.4.1.c_1
# Out:
# rm: `systems_test_stripes_5.4.1.c_1': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/mostLeastDenseWords.chqngh.20170620.052402.345258
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.052402.345258/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob9099915573594248503.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0369
#   Submitted application application_1497906899862_0369
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0369/
#   Running job: job_1497906899862_0369
#   Job job_1497906899862_0369 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0369 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.052402.345258/step-output/0000
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=563
# 	File Output Format Counters
# 		Bytes Written=810
# 	File System Counters
# 		FILE: Number of bytes read=447
# 		FILE: Number of bytes written=401330
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1025
# 		HDFS: Number of bytes written=810
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=50382336
# 		Total megabyte-milliseconds taken by all reduce tasks=66688000
# 		Total time spent by all map tasks (ms)=32801
# 		Total time spent by all maps in occupied slots (ms)=98403
# 		Total time spent by all reduce tasks (ms)=26050
# 		Total time spent by all reduces in occupied slots (ms)=130250
# 		Total vcore-milliseconds taken by all map tasks=32801
# 		Total vcore-milliseconds taken by all reduce tasks=26050
# 	Map-Reduce Framework
# 		CPU time spent (ms)=4600
# 		Combine input records=100
# 		Combine output records=33
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=239
# 		Input split bytes=462
# 		Map input records=10
# 		Map output bytes=1032
# 		Map output materialized bytes=477
# 		Map output records=100
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1905561600
# 		Reduce input groups=29
# 		Reduce input records=33
# 		Reduce output records=28
# 		Reduce shuffle bytes=477
# 		Shuffled Maps =2
# 		Spilled Records=66
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7749578752
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob278012974608998008.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0372
#   Submitted application application_1497906899862_0372
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0372/
#   Running job: job_1497906899862_0372
#   Job job_1497906899862_0372 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0372 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.052402.345258/output
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=1215
# 	File Output Format Counters
# 		Bytes Written=810
# 	File System Counters
# 		FILE: Number of bytes read=646
# 		FILE: Number of bytes written=401349
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1591
# 		HDFS: Number of bytes written=810
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=78434304
# 		Total megabyte-milliseconds taken by all reduce tasks=44444160
# 		Total time spent by all map tasks (ms)=51064
# 		Total time spent by all maps in occupied slots (ms)=153192
# 		Total time spent by all reduce tasks (ms)=17361
# 		Total time spent by all reduces in occupied slots (ms)=86805
# 		Total vcore-milliseconds taken by all map tasks=51064
# 		Total vcore-milliseconds taken by all reduce tasks=17361
# 	Map-Reduce Framework
# 		CPU time spent (ms)=4140
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=236
# 		Input split bytes=376
# 		Map input records=28
# 		Map output bytes=838
# 		Map output materialized bytes=783
# 		Map output records=28
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1908703232
# 		Reduce input groups=28
# 		Reduce input records=28
# 		Reduce output records=28
# 		Reduce shuffle bytes=783
# 		Shuffled Maps =2
# 		Spilled Records=56
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7721091072
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.052402.345258/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.052402.345258...
# Removing temp directory /tmp/mostLeastDenseWords.chqngh.20170620.052402.345258...
# WARNING:root:Elapsed time: 580.638614893 seconds
#     In minutes: 9.67731024822 mins

# %% [markdown]
# ### Most/Least Dense Words on Test Set Statistics:
#
# #### Time
# * _Run time: 91.82 seconds_
#
# * _Run time: 1.53 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 1275_
#
# * _Bytes Written: 850_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2660_

# %%
# !cat systems_test_stripes_5.4.1.c_1
# Out:
# "a"	-1.6094379124341003
# "in"	-2.2224382999704284
# "wales"	-2.3111921676467904
# "christmas"	-2.3111921676467904
# "child's"	-2.3111921676467904
# "of"	-2.3946529030299404
# "study"	-2.9097739241155969
# "case"	-2.9097739241155969
# "female"	-3.2107895274368428
# "collection"	-3.8368845701189014
# "the"	-4.4930665564453749
# "tales"	-4.501163766677994
# "fairy"	-4.501163766677994
# "forms"	-4.5597579309440475
# "government"	-4.6883753087661404
# "george"	-4.7915595450013715
# "general"	-4.7915595450013715
# "biography"	-4.7915595450013715
# "city"	-5.1862137370053203
# "circumstantial"	-5.1862137370053203
# "by"	-5.1862137370053203
# "sea"	-5.1862137370053203
# "narrative"	-5.1862137370053203
# "religious"	-5.2358106781446923
# "establishing"	-5.2358106781446923
# "for"	-5.2358106781446923
# "bill"	-5.2358106781446923
# "limited"	-5.3060149368179408

# %% [markdown]
# __On the full data set:__

# %%
# !hdfs dfs -rm -r full_mostLeastDenseWords_5.4.1.c
# !python mostLeastDenseWords.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ \
    --archive={pyArchive} \
    > full_mostLeastDenseWords_5.4.1.c
# Out:
# rm: `full_mostLeastDenseWords_5.4.1.c': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/mostLeastDenseWords.chqngh.20170620.053508.162054
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.053508.162054/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob3714992650099031291.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 190
#   number of splits:190
#   Submitting tokens for job: job_1497906899862_0373
#   Submitted application application_1497906899862_0373
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0373/
#   Running job: job_1497906899862_0373
#   Job job_1497906899862_0373 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 16% reduce 0%
#    map 17% reduce 0%
#    map 18% reduce 0%
#    map 19% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 22% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 40% reduce 0%
#    map 41% reduce 0%
#    map 42% reduce 0%
#    map 43% reduce 0%
#    map 44% reduce 0%
#    map 45% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 69% reduce 0%
#    map 70% reduce 0%
#    map 71% reduce 0%
#    map 72% reduce 0%
#    map 73% reduce 0%
#    map 74% reduce 0%
#    map 75% reduce 0%
#    map 76% reduce 0%
#    map 77% reduce 0%
#    map 78% reduce 0%
#    map 79% reduce 0%
#    map 80% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 83% reduce 0%
#    map 84% reduce 0%
#    map 85% reduce 0%
#    map 86% reduce 0%
#    map 87% reduce 0%
#    map 88% reduce 0%
#    map 89% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 67%
#    map 100% reduce 68%
#    map 100% reduce 69%
#    map 100% reduce 70%
#    map 100% reduce 71%
#    map 100% reduce 72%
#    map 100% reduce 73%
#    map 100% reduce 74%
#    map 100% reduce 75%
#    map 100% reduce 76%
#    map 100% reduce 77%
#    map 100% reduce 78%
#    map 100% reduce 79%
#    map 100% reduce 80%
#    map 100% reduce 81%
#    map 100% reduce 82%
#    map 100% reduce 83%
#    map 100% reduce 84%
#    map 100% reduce 85%
#    map 100% reduce 86%
#    map 100% reduce 87%
#    map 100% reduce 88%
#    map 100% reduce 89%
#    map 100% reduce 90%
#    map 100% reduce 91%
#    map 100% reduce 92%
#    map 100% reduce 93%
#    map 100% reduce 94%
#    map 100% reduce 95%
#    map 100% reduce 96%
#    map 100% reduce 97%
#    map 100% reduce 98%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497906899862_0373 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.053508.162054/step-output/0000
# Counters: 51
# 	File Input Format Counters
# 		Bytes Read=2156069116
# 	File Output Format Counters
# 		Bytes Written=8397356
# 	File System Counters
# 		FILE: Number of bytes read=39014926
# 		FILE: Number of bytes written=138294456
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2156101116
# 		HDFS: Number of bytes written=8397356
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=573
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=2
# 		Launched map tasks=192
# 		Launched reduce tasks=1
# 		Other local map tasks=2
# 		Rack-local map tasks=190
# 		Total megabyte-milliseconds taken by all map tasks=70602840576
# 		Total megabyte-milliseconds taken by all reduce tasks=332400640
# 		Total time spent by all map tasks (ms)=45965391
# 		Total time spent by all maps in occupied slots (ms)=137896173
# 		Total time spent by all reduce tasks (ms)=129844
# 		Total time spent by all reduces in occupied slots (ms)=649220
# 		Total vcore-milliseconds taken by all map tasks=45965391
# 		Total vcore-milliseconds taken by all reduce tasks=129844
# 	Map-Reduce Framework
# 		CPU time spent (ms)=29572750
# 		Combine input records=586822660
# 		Combine output records=6822933
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=169424
# 		Input split bytes=32000
# 		Map input records=58682266
# 		Map output bytes=5878243690
# 		Map output materialized bytes=73804117
# 		Map output records=586822660
# 		Merged Map outputs=190
# 		Physical memory (bytes) snapshot=155011444736
# 		Reduce input groups=269340
# 		Reduce input records=6822933
# 		Reduce output records=269339
# 		Reduce shuffle bytes=73804117
# 		Shuffled Maps =190
# 		Spilled Records=13645866
# 		Total committed heap usage (bytes)=294830735360
# 		Virtual memory (bytes) snapshot=421580296192
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob3267609344557477252.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0376
#   Submitted application application_1497906899862_0376
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0376/
#   Running job: job_1497906899862_0376
#   Job job_1497906899862_0376 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 82%
#    map 100% reduce 93%
#    map 100% reduce 100%
#   Job job_1497906899862_0376 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.053508.162054/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=8524054
# 	File Output Format Counters
# 		Bytes Written=8397356
# 	File System Counters
# 		FILE: Number of bytes read=3650721
# 		FILE: Number of bytes written=7815549
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=8524430
# 		HDFS: Number of bytes written=8397356
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=22264320
# 		Total megabyte-milliseconds taken by all reduce tasks=41446400
# 		Total time spent by all map tasks (ms)=14495
# 		Total time spent by all maps in occupied slots (ms)=43485
# 		Total time spent by all reduce tasks (ms)=16190
# 		Total time spent by all reduces in occupied slots (ms)=80950
# 		Total vcore-milliseconds taken by all map tasks=14495
# 		Total vcore-milliseconds taken by all reduce tasks=16190
# 	Map-Reduce Framework
# 		CPU time spent (ms)=17400
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=240
# 		Input split bytes=376
# 		Map input records=269339
# 		Map output bytes=8666695
# 		Map output materialized bytes=3764905
# 		Map output records=269339
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1943728128
# 		Reduce input groups=269339
# 		Reduce input records=269339
# 		Reduce output records=269339
# 		Reduce shuffle bytes=3764905
# 		Shuffled Maps =2
# 		Spilled Records=538678
# 		Total committed heap usage (bytes)=5202509824
# 		Virtual memory (bytes) snapshot=7754567680
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.053508.162054/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/mostLeastDenseWords.chqngh.20170620.053508.162054...
# Removing temp directory /tmp/mostLeastDenseWords.chqngh.20170620.053508.162054...
# WARNING:root:Elapsed time: 734.491249084 seconds
#     In minutes: 12.2415208181 mins

# %% [markdown]
# ### Most/Least Dense Words on Full Set Statistics:
#
# #### Time
# * _Run time: 713.76 seconds_
#
# * _Run time: 11.90 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 9313798_
#
# * _Bytes Written: 9190412_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 19600_

# %% [markdown]
# ## Highest frequency words

# %%
# !head -20 full_mostLeastDenseWords_5.4.1.c
# Out:
# "the"	-2.1997146286591951
# "of"	-2.5948415424832834
# "to"	-3.1017469641694286
# "in"	-3.5512104619731759
# "a"	-3.5944812861760083
# "and"	-3.7633969330906387
# "that"	-4.1222901645139665
# "is"	-4.1794296162291786
# "be"	-4.2757305602957727
# "as"	-4.6117218523743988
# "it"	-4.6218779855265648
# "was"	-4.6570322907820954
# "for"	-4.6735590741386348
# "not"	-4.8176584973674252
# "with"	-4.8807319433270129
# "on"	-4.9304593136462938
# "by"	-4.9607205141927553
# "he"	-5.0417326420258641
# "have"	-5.0502224848469091
# "which"	-5.1681749927840777

# %% [markdown]
# ## Lowest frequency words

# %%
# !tail -20 full_mostLeastDenseWords_5.4.1.c
#TODO revert order probably
# Out:
# "appartenants"	-20.937177779481853
# "imbodiment"	-20.937177779481853
# "hadrianopolin"	-20.937177779481853
# "anruf"	-20.937177779481853
# "apposito"	-20.937177779481853
# "ambrosiano"	-20.937177779481853
# "bashfulest"	-20.937177779481853
# "dtes"	-20.937177779481853
# "dtcd"	-20.937177779481853
# "falaba"	-20.937177779481853
# "karakaya"	-20.937177779481853
# "ampurdan"	-20.937177779481853
# "broster"	-20.937177779481853
# "greatgrandmother"	-20.937177779481853
# "croissy"	-20.937177779481853
# "greatlie"	-20.937177779481853
# "chawing"	-20.937177779481853
# "gottesheim's"	-20.937177779481853
# "boivant"	-20.937177779481853
# "anteponia"	-20.937177779481853

# %% [markdown]
# ## Word density MR stats
#
#     ec2_instance_type: m3.xlarge
#     num_ec2_instances: 15
#
# __Step 1:__
#
#     RUNNING for 649.2s  ~= 10 minutes
#     Launched map tasks=190
#     Launched reduce tasks=57
#
# __Step 2:__
#
#     RUNNING for 74.4s  ~= 1 minute
#     Launched map tasks=110
#     Launched reduce tasks=20

# %% [markdown]
# ### HW5.4.1 - D. Distribution of 5-gram sizes (character length)

# %%
# %%writefile distribution.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import time
import logging

class distribution(MRJob):
    
    # START STUDENT CODE 5.4.1.D
    
    MRJob.SORT_VALUES = True
        
    def mapper(self, _, line):
        
        # Split line
        splits = line.rstrip("\n").split("\t")
        words = splits[0].lower().split()
        
        char_count = 0
        
        # Count characters
        for word in words:
            char_count += len(word)
        
        yield char_count, 1
            
    
    def combiner(self, ngram_size, counts):
        yield ngram_size, sum(count for count in counts)
    
    def reducer(self, ngram_size, counts):
        yield ngram_size, sum(count for count in counts)

    def steps(self):
        
        custom_jobconf = {
            'stream.num.map.output.key.fields':'2',
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-k1,1n',
            'mapred.reduce.tasks': '1'
        }

        return [
                MRStep(
                    jobconf=custom_jobconf,
                    mapper=self.mapper,
                    reducer=self.reducer,
                    combiner = self.combiner)
        ]

    # END STUDENT CODE 5.4.1.D
    
if __name__ == '__main__':
    start_time = time.time()
    distribution.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting distribution.py

# %% [markdown]
# __On the test data set:__

# %%
# !hdfs dfs -rm -r 5.3distributions_test/part-00000
# !python distribution.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt \
    --archive={pyArchive} \
    > 5.3distributions_test
# Out:
# rm: `5.3distributions_test/part-00000': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/distribution.chqngh.20170620.062423.465617
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062423.465617/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob8381290778476952005.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0389
#   Submitted application application_1497906899862_0389
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0389/
#   Running job: job_1497906899862_0389
#   Job job_1497906899862_0389 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0389 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062423.465617/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=563
# 	File Output Format Counters
# 		Bytes Written=45
# 	File System Counters
# 		FILE: Number of bytes read=68
# 		FILE: Number of bytes written=401273
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1011
# 		HDFS: Number of bytes written=45
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=18385920
# 		Total megabyte-milliseconds taken by all reduce tasks=9541120
# 		Total time spent by all map tasks (ms)=11970
# 		Total time spent by all maps in occupied slots (ms)=35910
# 		Total time spent by all reduce tasks (ms)=3727
# 		Total time spent by all reduces in occupied slots (ms)=18635
# 		Total vcore-milliseconds taken by all map tasks=11970
# 		Total vcore-milliseconds taken by all reduce tasks=3727
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2750
# 		Combine input records=10
# 		Combine output records=10
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=112
# 		Input split bytes=448
# 		Map input records=10
# 		Map output bytes=60
# 		Map output materialized bytes=88
# 		Map output records=10
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1896816640
# 		Reduce input groups=9
# 		Reduce input records=10
# 		Reduce output records=9
# 		Reduce shuffle bytes=88
# 		Shuffled Maps =2
# 		Spilled Records=20
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7730339840
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062423.465617/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062423.465617...
# Removing temp directory /tmp/distribution.chqngh.20170620.062423.465617...
# WARNING:root:Elapsed time: 55.0048599243 seconds
#     In minutes: 0.916747665405 mins

# %% [markdown]
# ### 5 Gram Disttribution on Test Set Statistics:
#
# #### Time
# * _Run time: 65.28 seconds_
#
# * _Run time: 1.09 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 563_
#
# * _Bytes Written: 45_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3340_

# %%
# !cat 5.3distributions_test
# Out:
# 13	1
# 18	1
# 19	1
# 20	1
# 22	1
# 23	1
# 24	1
# 25	1
# 29	2

# %% [markdown]
# ## Test Histogram 10-line test

# %%
# %matplotlib inline
import numpy as np
import pylab as pl

results_A = []
for line in open("5.3distributions_test").readlines():
    line = line.strip()
    X,Y = line.split("\t")
    results_A.append([int(X),int(Y)])

items = (np.array(results_A)[::-1].T)
fig = pl.figure(figsize=(17,7))
ax = pl.subplot(111)
width=0.8
ax.bar(range(len(items[0])), items[1], width=width)
ax.set_xticks(np.arange(len(items[0])) + width/2)
ax.set_xticklabels(items[0], rotation=90)
ax.invert_xaxis()


pl.title("Distributions of 5 Gram lengths in 10-line test")
pl.show()

# %% [markdown]
# __On the full data set:__

# %%
# !hdfs dfs -rm -r full_distribution_5.4.1.d
# !python distribution.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ \
    --archive={pyArchive} \
    > full_distribution_5.4.1.d
# Out:
# rm: `full_distribution_5.4.1.d': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/distribution.chqngh.20170620.062546.647199
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062546.647199/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob2097430493250368685.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 190
#   number of splits:190
#   Submitting tokens for job: job_1497906899862_0390
#   Submitted application application_1497906899862_0390
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0390/
#   Running job: job_1497906899862_0390
#   Job job_1497906899862_0390 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 5% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 13% reduce 0%
#    map 15% reduce 0%
#    map 17% reduce 0%
#    map 19% reduce 0%
#    map 21% reduce 0%
#    map 23% reduce 0%
#    map 25% reduce 0%
#    map 27% reduce 0%
#    map 29% reduce 0%
#    map 31% reduce 0%
#    map 34% reduce 0%
#    map 36% reduce 0%
#    map 38% reduce 0%
#    map 41% reduce 0%
#    map 44% reduce 0%
#    map 46% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 61% reduce 0%
#    map 64% reduce 0%
#    map 67% reduce 0%
#    map 69% reduce 0%
#    map 71% reduce 0%
#    map 74% reduce 0%
#    map 76% reduce 0%
#    map 77% reduce 0%
#    map 78% reduce 0%
#    map 79% reduce 0%
#    map 81% reduce 0%
#    map 84% reduce 0%
#    map 86% reduce 0%
#    map 87% reduce 0%
#    map 88% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0390 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062546.647199/output
# Counters: 51
# 	File Input Format Counters
# 		Bytes Read=2156069116
# 	File Output Format Counters
# 		Bytes Written=619
# 	File System Counters
# 		FILE: Number of bytes read=29461
# 		FILE: Number of bytes written=25629934
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2156101116
# 		HDFS: Number of bytes written=619
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=573
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=191
# 		Launched reduce tasks=1
# 		Other local map tasks=2
# 		Rack-local map tasks=189
# 		Total megabyte-milliseconds taken by all map tasks=16205581824
# 		Total megabyte-milliseconds taken by all reduce tasks=10634240
# 		Total time spent by all map tasks (ms)=10550509
# 		Total time spent by all maps in occupied slots (ms)=31651527
# 		Total time spent by all reduce tasks (ms)=4154
# 		Total time spent by all reduces in occupied slots (ms)=20770
# 		Total vcore-milliseconds taken by all map tasks=10550509
# 		Total vcore-milliseconds taken by all reduce tasks=4154
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3900930
# 		Combine input records=58682266
# 		Combine output records=9172
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=79792
# 		Input split bytes=32000
# 		Map input records=58682266
# 		Map output bytes=352088828
# 		Map output materialized bytes=79220
# 		Map output records=58682266
# 		Merged Map outputs=190
# 		Physical memory (bytes) snapshot=154568994816
# 		Reduce input groups=80
# 		Reduce input records=9172
# 		Reduce output records=80
# 		Reduce shuffle bytes=79220
# 		Shuffled Maps =190
# 		Spilled Records=18344
# 		Total committed heap usage (bytes)=299992875008
# 		Virtual memory (bytes) snapshot=421147045888
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062546.647199/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/distribution.chqngh.20170620.062546.647199...
# Removing temp directory /tmp/distribution.chqngh.20170620.062546.647199...
# WARNING:root:Elapsed time: 139.723877192 seconds
#     In minutes: 2.32873128653 mins

# %% [markdown]
# ### 5 Gram Distribution on Full Set Statistics:
#
# #### Time
# * _Run time: 156.67 seconds_
#
# * _Run time: 2.61 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 2156069116_
#
# * _Bytes Written: 619_
#
# #### Cluster Resources
# * _Number of Mappers: 191_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 3964310_

# %% [markdown]
# ## Distribution MRJob stats
#
# __Step 1:__
#
#     RUNNING for 157.8s ~= 2.6 minutes
#     Launched map tasks=191
#     Launched reduce tasks=16
#
# __Step 2:__
#
#     RUNNING for 115.0s ~= 2 minutes
#     Launched map tasks=139
# 	Launched reduce tasks=1

# %%
# %matplotlib inline
import numpy as np
import pylab as pl

results_A = []
for line in open("full_distribution_5.4.1.d").readlines():
    line = line.strip()
    X,Y = line.split("\t")
    results_A.append([int(X),int(Y)])

items = (np.array(results_A)[::-1].T)
fig = pl.figure(figsize=(17,7))
ax = pl.subplot(111)
width=0.8
ax.bar(range(len(items[0])), items[1], width=width)
ax.set_xticks(np.arange(len(items[0])) + width/2)
ax.set_xticklabels(items[0], rotation=90)
ax.invert_xaxis()


pl.title("Distributions of 5 Gram lengths")
pl.show()

# %% [markdown]
# ## 3.  HW5.4.2 <a name="5.4.2"></a>OPTIONAL Question: log-log plots (PHASE 2)
# [Back to Table of Contents](#TOC)
#
# Plot the log-log plot of the frequency distributuion of unigrams. Does it follow power law distribution?
#
# For more background see:
# - https://en.wikipedia.org/wiki/Log%E2%80%93log_plot
# - https://en.wikipedia.org/wiki/Power_law

# %%
# %matplotlib inline
import numpy as np
import pylab as plt

X = []
Y = []

for line in open("full_distribution_5.4.1.d").readlines():
    line = line.strip()
    x, y  = map(int, line.split("\t"))
    X.append(x)
    Y.append(y)
    
plt.loglog(X, Y)


plt.title("Log-log frequency distribution of unigrams")
plt.show()

# %% [markdown]
# ## 3.  HW5.5  <a name="5.5"></a> Synonym detection over 2Gig of Data with extra Preprocessing steps (HW5.3 plus some preprocessing)   (Phase 2)
# [Back to Table of Contents](#TOC)
#
# For the remainder of this assignment please feel free to eliminate stop words from your analysis

# %% [markdown]
# >There is also a corpus of stopwords, that is, high-frequency words like "the", "to" and "also" that we sometimes want to filter out of a document before further processing. Stopwords usually have little lexical content, and their presence in a text fails to distinguish it from other texts. Python's nltk comes with a prebuilt list of stopwords (see below). Using this stopword list filter out these tokens from your analysis and rerun the experiments in 5.5 and disucuss the results of using a stopword list and without using a stopword list.
#
# > from nltk.corpus import stopwords
#  stopwords.words('english')
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
# 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
# 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
# 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
# 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
# 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
# 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
# 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
# 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
# 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
# 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
# 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %% [markdown]
# ### 2: A large subset of the Google n-grams dataset as was described above
#
# For each HW 5.4 -5.5.1 Please unit test and system test your code with respect
# to SYSTEMS TEST DATASET and show the results.
# Please compute the expected answer by hand and show your hand calculations for the
# SYSTEMS TEST DATASET. Then show the results you get with your system.

# %% [markdown]
# In this part of the assignment we will focus on developing methods for detecting synonyms, using the Google 5-grams dataset. At a high level:
#
#
# 1. remove stopwords
# 2. get 10,0000 most frequent
# 3. get 1000 (9001-10000) features
# 3. build stripes
#
# To accomplish this you must script two main tasks using MRJob:
#
#
# __TASK (1)__ Build stripes for the most frequent 10,000 words using cooccurence information based on
# the words ranked from 9001,-10,000 as a basis/vocabulary (drop stopword-like terms),
# and output to a file in your bucket on s3 (bigram analysis, though the words are non-contiguous).
#
#
# __TASK (2)__ Using two (symmetric) comparison methods of your choice
# (e.g., correlations, distances, similarities), pairwise compare
# all stripes (vectors), and output to a file in your bucket on s3.
#
# #### Design notes for TASK (1)
# For this task you will be able to modify the pattern we used in HW 3.2
# (feel free to use the solution as reference). To total the word counts
# across the 5-grams, output the support from the mappers using the total
# order inversion pattern:
#
# <*word,count>
#
# to ensure that the support arrives before the cooccurrences.
#
# In addition to ensuring the determination of the total word counts,
# the mapper must also output co-occurrence counts for the pairs of
# words inside of each 5-gram. Treat these words as a basket,
# as we have in HW 3, but count all stripes or pairs in both orders,
# i.e., count both orderings: (word1,word2), and (word2,word1), to preserve
# symmetry in our output for TASK (2).
#
# #### Design notes for _TASK (2)_
# For this task you will have to determine a method of comparison.
# Here are a few that you might consider:
#
# - Jaccard
# - Cosine similarity
# - Spearman correlation
# - Euclidean distance
# - Taxicab (Manhattan) distance
# - Shortest path graph distance (a graph, because our data is symmetric!)
# - Pearson correlation
# - Kendall correlation
#
# However, be cautioned that some comparison methods are more difficult to
# parallelize than others, and do not perform more associations than is necessary,
# since your choice of association will be symmetric.
#
# Please use the inverted index (discussed in live session #5) based pattern to compute the pairwise (term-by-term) similarity matrix.
#
# Please report the size of the cluster used and the amount of time it takes to run for the index construction task and for the synonym calculation task. How many pairs need to be processed (HINT: use the posting list length to calculate directly)? Report your  Cluster configuration!

# %% [markdown]
# ## Example MR stats: (report times!)
#     took ~11 minutes on 5 m3.xlarge nodes
#     Data-local map tasks=188
# 	Launched map tasks=190
# 	Launched reduce tasks=15
# 	Other local map tasks=2

# %%
# START STUDENT CODE 5.5
# ADD OR REMOVE CELLS AS NEEDED

# %% [markdown]
# ## Frequency ranking

# %%
# %%writefile frequencies5_5.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import re

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import time
import logging

class frequencies(MRJob):

    # START STUDENT CODE 5.4.1.B
    
    MRJob.SORT_VALUES = True
        
    def __init__(self, args):
        super(frequencies, self).__init__(args)
        #self.min_rank = 9001
        #self.max_rank = 10000 
        self.current_rank = 0

    def configure_options(self): 
        super(frequencies, self).configure_options() 
        self.add_passthrough_option('--min_rank', dest='min_rank', type='int', default=9001) 
        self.add_passthrough_option('--max_rank', dest='max_rank', type='int', default=10000) 
    
    def mapper(self, _, line):
        
        # Split line
        splits = line.rstrip("\n").split("\t")
        words = splits[0].lower().split()
        count = int(splits[1])
        
        for word in words:
            yield word, count
            
    
    def combiner(self, word, counts):
        total = sum(count for count in counts)
        yield word, total
    
    def reducer(self, word, counts):
        total = sum(count for count in counts)
        yield total, word
    
    def max_reducer(self, count, words):
        
        # Words come in frequency descending order here
        # Only yield the words that are within the min and max frequency ranking desired
        
        for word in words:
            self.current_rank += 1
            
            if self.current_rank >= self.options.min_rank and self.current_rank <= self.options.max_rank:
                yield word, count

    def steps(self):
        
        custom_jobconf = {
            'stream.num.map.output.key.fields':'2',
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-k1,1nr',
            'mapred.reduce.tasks': '1'
        }

        return [
                MRStep(mapper=self.mapper,
                    reducer=self.reducer,
                    combiner = self.combiner),
                MRStep(jobconf=custom_jobconf,
                       reducer=self.max_reducer)
                 ]

    # END STUDENT CODE 5.4.1.B
        
if __name__ == '__main__':
    start_time = time.time()
    frequencies.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting frequencies5_5.py

# %% [markdown]
# ### Frequency ranking on 10-line test dataset

# %%
# !hdfs dfs -rm -r frequencies_test5.5
# !python frequencies5_5.py --min_rank 2 --max_rank 4 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt \
    --archive={pyArchive} \
    > frequencies_test5.5
# Out:
# rm: `frequencies_test5.5': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/frequencies5_5.chqngh.20170620.062905.419577
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.062905.419577/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob6556139110631176319.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0393
#   Submitted application application_1497906899862_0393
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0393/
#   Running job: job_1497906899862_0393
#   Job job_1497906899862_0393 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0393 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.062905.419577/step-output/0000
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=563
# 	File Output Format Counters
# 		Bytes Written=357
# 	File System Counters
# 		FILE: Number of bytes read=430
# 		FILE: Number of bytes written=401288
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1015
# 		HDFS: Number of bytes written=357
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=11582976
# 		Total megabyte-milliseconds taken by all reduce tasks=10636800
# 		Total time spent by all map tasks (ms)=7541
# 		Total time spent by all maps in occupied slots (ms)=22623
# 		Total time spent by all reduce tasks (ms)=4155
# 		Total time spent by all reduces in occupied slots (ms)=20775
# 		Total vcore-milliseconds taken by all map tasks=7541
# 		Total vcore-milliseconds taken by all reduce tasks=4155
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2960
# 		Combine input records=50
# 		Combine output records=31
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=94
# 		Input split bytes=452
# 		Map input records=10
# 		Map output bytes=602
# 		Map output materialized bytes=458
# 		Map output records=50
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1913286656
# 		Reduce input groups=28
# 		Reduce input records=31
# 		Reduce output records=28
# 		Reduce shuffle bytes=458
# 		Shuffled Maps =2
# 		Spilled Records=62
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7764369408
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob5611784805383957441.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0394
#   Submitted application application_1497906899862_0394
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0394/
#   Running job: job_1497906899862_0394
#   Job job_1497906899862_0394 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0394 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.062905.419577/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=536
# 	File Output Format Counters
# 		Bytes Written=40
# 	File System Counters
# 		FILE: Number of bytes read=396
# 		FILE: Number of bytes written=400615
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=902
# 		HDFS: Number of bytes written=40
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=19043328
# 		Total megabyte-milliseconds taken by all reduce tasks=10270720
# 		Total time spent by all map tasks (ms)=12398
# 		Total time spent by all maps in occupied slots (ms)=37194
# 		Total time spent by all reduce tasks (ms)=4012
# 		Total time spent by all reduces in occupied slots (ms)=20060
# 		Total vcore-milliseconds taken by all map tasks=12398
# 		Total vcore-milliseconds taken by all reduce tasks=4012
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2630
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=92
# 		Input split bytes=366
# 		Map input records=28
# 		Map output bytes=385
# 		Map output materialized bytes=437
# 		Map output records=28
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1907843072
# 		Reduce input groups=28
# 		Reduce input records=28
# 		Reduce output records=3
# 		Reduce shuffle bytes=437
# 		Shuffled Maps =2
# 		Spilled Records=56
# 		Total committed heap usage (bytes)=5218762752
# 		Virtual memory (bytes) snapshot=7780671488
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.062905.419577/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.062905.419577...
# Removing temp directory /tmp/frequencies5_5.chqngh.20170620.062905.419577...
# WARNING:root:Elapsed time: 84.463999033 seconds
#     In minutes: 1.40773331722 mins

# %% [markdown]
# ### Frequencies on Test Set Statistics:
#
# #### Time
# * _Run time: 87.94 seconds_
#
# * _Run time: 1.47 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 536_
#
# * _Bytes Written: 40_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 2480_

# %%
# !cat frequencies_test5.5
# Out:
# "in"	1201
# "wales"	1099
# "christmas"	1099

# %% [markdown]
# ### Frequency ranking on full dataset

# %%
# !hdfs dfs -rm -r frequencies5.5
# !python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ \
    --archive={pyArchive} \
    > frequencies5.5
# Out:
# rm: `frequencies5.5': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/frequencies5_5.chqngh.20170620.063118.139270
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.063118.139270/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob8123320001928748870.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 190
#   number of splits:190
#   Submitting tokens for job: job_1497906899862_0396
#   Submitted application application_1497906899862_0396
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0396/
#   Running job: job_1497906899862_0396
#   Job job_1497906899862_0396 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 16% reduce 0%
#    map 17% reduce 0%
#    map 18% reduce 0%
#    map 19% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 22% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 40% reduce 0%
#    map 41% reduce 0%
#    map 42% reduce 0%
#    map 43% reduce 0%
#    map 44% reduce 0%
#    map 45% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 69% reduce 0%
#    map 70% reduce 0%
#    map 71% reduce 0%
#    map 72% reduce 0%
#    map 73% reduce 0%
#    map 74% reduce 0%
#    map 75% reduce 0%
#    map 76% reduce 0%
#    map 77% reduce 0%
#    map 78% reduce 0%
#    map 79% reduce 0%
#    map 80% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 83% reduce 0%
#    map 85% reduce 0%
#    map 86% reduce 0%
#    map 87% reduce 0%
#    map 88% reduce 0%
#    map 89% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 67%
#    map 100% reduce 68%
#    map 100% reduce 69%
#    map 100% reduce 70%
#    map 100% reduce 71%
#    map 100% reduce 72%
#    map 100% reduce 73%
#    map 100% reduce 74%
#    map 100% reduce 75%
#    map 100% reduce 76%
#    map 100% reduce 77%
#    map 100% reduce 78%
#    map 100% reduce 79%
#    map 100% reduce 80%
#    map 100% reduce 81%
#    map 100% reduce 82%
#    map 100% reduce 83%
#    map 100% reduce 84%
#    map 100% reduce 85%
#    map 100% reduce 86%
#    map 100% reduce 87%
#    map 100% reduce 88%
#    map 100% reduce 89%
#    map 100% reduce 90%
#    map 100% reduce 91%
#    map 100% reduce 92%
#    map 100% reduce 93%
#    map 100% reduce 94%
#    map 100% reduce 95%
#    map 100% reduce 96%
#    map 100% reduce 97%
#    map 100% reduce 98%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497906899862_0396 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.063118.139270/step-output/0000
# Counters: 51
# 	File Input Format Counters
# 		Bytes Read=2156069116
# 	File Output Format Counters
# 		Bytes Written=4158739
# 	File System Counters
# 		FILE: Number of bytes read=39013260
# 		FILE: Number of bytes written=138275092
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2156101116
# 		HDFS: Number of bytes written=4158739
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=573
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=2
# 		Launched map tasks=192
# 		Launched reduce tasks=1
# 		Other local map tasks=2
# 		Rack-local map tasks=190
# 		Total megabyte-milliseconds taken by all map tasks=42591275520
# 		Total megabyte-milliseconds taken by all reduce tasks=315381760
# 		Total time spent by all map tasks (ms)=27728695
# 		Total time spent by all maps in occupied slots (ms)=83186085
# 		Total time spent by all reduce tasks (ms)=123196
# 		Total time spent by all reduces in occupied slots (ms)=615980
# 		Total vcore-milliseconds taken by all map tasks=27728695
# 		Total vcore-milliseconds taken by all reduce tasks=123196
# 	Map-Reduce Framework
# 		CPU time spent (ms)=15381710
# 		Combine input records=293411330
# 		Combine output records=6822745
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=116690
# 		Input split bytes=32000
# 		Map input records=58682266
# 		Map output bytes=3430141090
# 		Map output materialized bytes=73800744
# 		Map output records=293411330
# 		Merged Map outputs=190
# 		Physical memory (bytes) snapshot=154566950912
# 		Reduce input groups=269339
# 		Reduce input records=6822745
# 		Reduce output records=269339
# 		Reduce shuffle bytes=73800744
# 		Shuffled Maps =190
# 		Spilled Records=13645490
# 		Total committed heap usage (bytes)=298289987584
# 		Virtual memory (bytes) snapshot=421313343488
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob8085671516787287216.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0398
#   Submitted application application_1497906899862_0398
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0398/
#   Running job: job_1497906899862_0398
#   Job job_1497906899862_0398 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_0398 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.063118.139270/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=4176522
# 	File Output Format Counters
# 		Bytes Written=17944
# 	File System Counters
# 		FILE: Number of bytes read=2953963
# 		FILE: Number of bytes written=6322927
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=4176888
# 		HDFS: Number of bytes written=17944
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=20347392
# 		Total megabyte-milliseconds taken by all reduce tasks=23928320
# 		Total time spent by all map tasks (ms)=13247
# 		Total time spent by all maps in occupied slots (ms)=39741
# 		Total time spent by all reduce tasks (ms)=9347
# 		Total time spent by all reduces in occupied slots (ms)=46735
# 		Total vcore-milliseconds taken by all map tasks=13247
# 		Total vcore-milliseconds taken by all reduce tasks=9347
# 	Map-Reduce Framework
# 		CPU time spent (ms)=12700
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=175
# 		Input split bytes=366
# 		Map input records=269339
# 		Map output bytes=4428078
# 		Map output materialized bytes=2969260
# 		Map output records=269339
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1955897344
# 		Reduce input groups=269339
# 		Reduce input records=269339
# 		Reduce output records=1000
# 		Reduce shuffle bytes=2969260
# 		Shuffled Maps =2
# 		Spilled Records=538678
# 		Total committed heap usage (bytes)=5201461248
# 		Virtual memory (bytes) snapshot=7744659456
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.063118.139270/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/frequencies5_5.chqngh.20170620.063118.139270...
# Removing temp directory /tmp/frequencies5_5.chqngh.20170620.063118.139270...
# WARNING:root:Elapsed time: 543.779367924 seconds
#     In minutes: 9.0629894654 mins

# %% [markdown]
# ### Frequencies on Full Set Statistics:
#
# #### Time
# * _Run time: 477.21 seconds_
#
# * _Run time: 8.14 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 2156069116_
#
# * _Bytes Written: 4158739_
#
# #### Cluster Resources
# * _Number of Mappers: 191_
#
# * _Number of Reducers: 1_
#
# * _CPU time spent: 15443020_

# %%
# !cat frequencies5.5
# Out:
# "surveys"	169333
# "jungle"	169314
# "lacked"	169282
# "correlate"	169273
# "boxes"	169237
# "escort"	169220
# "disclosed"	169132
# "shepherd"	169114
# "commend"	169081
# "zenith"	169049
# "multiplication"	169025
# "epic"	169004
# "literacy"	168967
# "atonement"	168908
# "soda"	168897
# "necrosis"	168894
# "initially"	168891
# "compounded"	168832
# "compressed"	168825
# "bade"	168815
# "confidential"	168713
# "monitored"	168709
# "residing"	168694
# "shortcomings"	168632
# "disclosure"	168627
# "sulphate"	168511
# "composite"	168469
# "evenly"	168458
# "nephew"	168409
# "canoe"	168402
# "miseries"	168377
# "ethic"	168374
# "cathode"	168348
# "proportionate"	168341
# "treats"	168325
# "speedily"	168322
# "impart"	168307
# "stipulated"	168278
# "hygiene"	168271
# "palestinian"	168244
# "convergence"	168145
# "maxim"	168097
# "schooling"	168053
# "annum"	168038
# "shrink"	168034
# "ribs"	167948
# "recognizes"	167929
# "ridicule"	167904
# "acetic"	167850
# "diminishing"	167800
# "populous"	167697
# "threads"	167685
# "protestants"	167678
# "hailed"	167633
# "completeness"	167597
# "spectators"	167553
# "israelites"	167528
# "lymphocytes"	167490
# "surest"	167434
# "tricks"	167353
# "autosomal"	167343
# "neat"	167338
# "hoc"	167228
# "paces"	167196
# "rigorous"	167184
# "commence"	167135
# "distrust"	167132
# "inferences"	167052
# "brightest"	167049
# "derivatives"	167006
# "honors"	166916
# "lengthy"	166744
# "consulting"	166721
# "hints"	166714
# "practitioner"	166632
# "rushing"	166603
# "aperture"	166597
# "infusion"	166594
# "pleaded"	166570
# "adolescence"	166560
# "allah"	166503
# "trent"	166484
# "thereto"	166469
# "uterine"	166422
# "marriages"	166388
# "defective"	166388
# "structured"	166380
# "slender"	166356
# "disruption"	166345
# "swell"	166342
# "profoundly"	166329
# "fossil"	166307
# "chronological"	166300
# "butt"	166297
# "likened"	166273
# "resembling"	166243
# "ecological"	166174
# "denmark"	166148
# "localized"	166144
# "jones"	166118
# "loading"	166105
# "forthcoming"	166037
# "laser"	166027
# "lt"	166027
# "screening"	165948
# "adopting"	165947
# "employing"	165895
# "preponderance"	165842
# "rs"	165728
# "printer"	165606
# "kicked"	165599
# "occupying"	165572
# "expressive"	165541
# "vogue"	165501
# "balcony"	165442
# "contributors"	165414
# "jackson"	165372
# "scandal"	165358
# "cornea"	165335
# "diversion"	165328
# "investigating"	165325
# "amidst"	165313
# "inhibit"	165264
# "individuality"	165261
# "sterling"	165162
# "funding"	165111
# "cooled"	165040
# "attendant"	165029
# "dismissal"	165027
# "classify"	165009
# "avowed"	164983
# "adviser"	164963
# "bucket"	164933
# "pitched"	164927
# "victories"	164832
# "ceded"	164782
# "restless"	164743
# "narrator"	164661
# "danube"	164644
# "telescope"	164633
# "bidding"	164624
# "careless"	164610
# "discontent"	164546
# "night's"	164516
# "alphabet"	164407
# "robe"	164292
# "remission"	164256
# "ordinances"	164246
# "ink"	164202
# "hasty"	164137
# "statesmen"	164110
# "dumb"	164022
# "subdivided"	163907
# "initiate"	163704
# "futility"	163578
# "adduced"	163563
# "proclaim"	163470
# "interpreter"	163384
# "roses"	163306
# "accumulate"	163263
# "doings"	163215
# "specifications"	163140
# "flashed"	163119
# "revealing"	163103
# "thereafter"	163097
# "lawn"	163093
# "bourgeois"	163062
# "experiencing"	163051
# "pathological"	162907
# "alveolar"	162782
# "unusually"	162777
# "troop"	162770
# "parked"	162735
# "fiery"	162714
# "implementing"	162675
# "insoluble"	162668
# "wording"	162667
# "contradict"	162625
# "buffer"	162589
# "damned"	162540
# "hungary"	162461
# "exhaustion"	162460
# "infringement"	162445
# "essentials"	162418
# "dew"	162391
# "coats"	162368
# "ushered"	162358
# "mast"	162347
# "whither"	162335
# "spoil"	162334
# "altering"	162329
# "unfortunately"	162314
# "agrarian"	162300
# "guides"	162297
# "negation"	162147
# "yielding"	162013
# "sequences"	162006
# "maiden"	161915
# "flourish"	161887
# "traitor"	161866
# "spur"	161834
# "thames"	161814
# "pancreas"	161739
# "deficiencies"	161709
# "inherit"	161665
# "franklin"	161630
# "flush"	161538
# "holocaust"	161537
# "unstable"	161450
# "episodes"	161424
# "redeem"	161417
# "stationary"	161322
# "pilgrims"	161315
# "intrusted"	161314
# "wasting"	161307
# "lobes"	161287
# "dictate"	161244
# "refinement"	161231
# "capitol"	161218
# "articulation"	161141
# "brand"	161113
# "conqueror"	161112
# "inferiority"	161097
# "suggestive"	161085
# "serpent"	161018
# "sued"	160892
# "overlooking"	160886
# "genre"	160837
# "repentance"	160812
# "originate"	160798
# "silly"	160760
# "impatience"	160746
# "centered"	160715
# "whoever"	160690
# "banquet"	160663
# "hinted"	160599
# "localities"	160589
# "deserving"	160559
# "indebtedness"	160500
# "insane"	160452
# "reagan"	160450
# "roofs"	160448
# "grandmother"	160442
# "flocks"	160401
# "spoils"	160333
# "residual"	160329
# "inception"	160308
# "maintains"	160244
# "nova"	160225
# "discrete"	160190
# "expanse"	160173
# "rods"	160144
# "sermons"	160110
# "commandment"	160074
# "bitterly"	160070
# "afterward"	160068
# "operative"	159942
# "revert"	159878
# "analyzing"	159811
# "indicators"	159748
# "habitation"	159699
# "spy"	159675
# "effectually"	159674
# "tribune"	159623
# "confinement"	159534
# "affiliated"	159510
# "vibrations"	159501
# "relish"	159487
# "finishing"	159389
# "punishments"	159344
# "drinks"	159320
# "coronation"	159282
# "cleaned"	159279
# "tv"	159194
# "underestimate"	159180
# "cartilage"	159072
# "ft"	159011
# "wires"	158905
# "crazy"	158860
# "peritoneal"	158740
# "sympathies"	158627
# "rabbit"	158582
# "generic"	158539
# "denoted"	158528
# "licence"	158528
# "endowment"	158477
# "generalization"	158456
# "fallacy"	158397
# "alternate"	158384
# "mate"	158378
# "examinations"	158376
# "myths"	158363
# "sunset"	158323
# "tangible"	158279
# "intervening"	158263
# "abnormalities"	158253
# "amiable"	158193
# "imputed"	158166
# "amply"	158157
# "trapped"	158142
# "commonest"	158105
# "designing"	158048
# "subscribed"	158043
# "arthritis"	158020
# "accusation"	157905
# "diffuse"	157857
# "wax"	157767
# "xiv"	157732
# "detroit"	157663
# "lends"	157660
# "funded"	157657
# "unfamiliar"	157650
# "auxiliary"	157641
# "dreaded"	157614
# "eastward"	157543
# "complexion"	157473
# "decoration"	157371
# "warrior"	157357
# "captive"	157317
# "morphology"	157315
# "flourished"	157303
# "foreground"	157190
# "cage"	157134
# "misfortunes"	157066
# "enmity"	157051
# "suspend"	156952
# "upstairs"	156866
# "tracing"	156762
# "mastered"	156755
# "analysed"	156705
# "rains"	156646
# "unwillingness"	156618
# "packet"	156551
# "admitting"	156500
# "natures"	156458
# "pink"	156443
# "lever"	156374
# "err"	156346
# "clan"	156334
# "extracellular"	156329
# "anonymous"	156325
# "meridian"	156288
# "habitual"	156283
# "benevolent"	156244
# "sketches"	156215
# "charitable"	156186
# "crosses"	156156
# "optimistic"	156113
# "lattice"	156108
# "synthetic"	156065
# "plunge"	156060
# "dearest"	156040
# "excesses"	156018
# "slice"	155963
# "widening"	155957
# "purest"	155932
# "sri"	155902
# "rite"	155885
# "linen"	155853
# "osmotic"	155852
# "bedside"	155812
# "farthest"	155791
# "consul"	155653
# "fare"	155620
# "homer"	155560
# "elevator"	155544
# "versailles"	155396
# "rivalry"	155387
# "waged"	155387
# "pretending"	155318
# "irresistible"	155281
# "judicious"	155236
# "programmes"	155209
# "balls"	155204
# "dielectric"	155183
# "swords"	155181
# "steamer"	155152
# "purview"	155146
# "tuesday"	155142
# "jointly"	155126
# "colonization"	155125
# "architectural"	155086
# "fascination"	155003
# "tumult"	154967
# "officially"	154967
# "cleft"	154963
# "synod"	154916
# "unprecedented"	154914
# "skeletal"	154913
# "questioning"	154890
# "cons"	154884
# "mitral"	154844
# "sweeping"	154808
# "sanitary"	154807
# "marching"	154765
# "perimeter"	154640
# "shareholders"	154566
# "damp"	154441
# "aversion"	154377
# "phosphorus"	154374
# "residential"	154336
# "avoidance"	154311
# "cart"	154290
# "wholesale"	154269
# "brother's"	154225
# "entropy"	154172
# "impacts"	154170
# "firmness"	154163
# "wills"	154083
# "careers"	154051
# "interpersonal"	153983
# "inmates"	153934
# "commonplace"	153829
# "contradictory"	153825
# "groundwork"	153793
# "graceful"	153721
# "hearth"	153691
# "violating"	153588
# "buenos"	153560
# "approximated"	153559
# "weep"	153556
# "informing"	153542
# "pores"	153522
# "hundredth"	153513
# "ether"	153511
# "sabha"	153474
# "obscured"	153473
# "hungarian"	153428
# "oblige"	153425
# "shouts"	153335
# "vicissitudes"	153223
# "awaken"	153207
# "politically"	153205
# "hue"	153127
# "digestion"	153125
# "americas"	153124
# "curb"	153108
# "barbarous"	153100
# "debated"	152990
# "sinner"	152989
# "presumably"	152894
# "alaska"	152850
# "foe"	152840
# "recollections"	152755
# "sack"	152743
# "repaid"	152737
# "amazement"	152730
# "prussian"	152722
# "pyramid"	152684
# "voyages"	152671
# "bombing"	152661
# "kinship"	152648
# "filtered"	152622
# "temperament"	152621
# "collateral"	152607
# "relaxed"	152602
# "transitional"	152577
# "energetic"	152565
# "paradigm"	152562
# "psychoanalytic"	152515
# "forts"	152483
# "enriched"	152475
# "advertisement"	152449
# "ie"	152372
# "doctor's"	152368
# "floors"	152311
# "offerings"	152271
# "vault"	152216
# "expects"	152195
# "distressed"	152148
# "tore"	152142
# "oblique"	152139
# "holdings"	152133
# "ugly"	152130
# "discerned"	152117
# "mould"	152086
# "immunities"	152072
# "gentry"	152066
# "elapse"	152037
# "logically"	151994
# "catalog"	151989
# "stead"	151963
# "renounce"	151923
# "scarlet"	151885
# "clearance"	151851
# "chimney"	151846
# "honestly"	151766
# "assisting"	151702
# "inflict"	151593
# "faction"	151569
# "spake"	151532
# "designer"	151438
# "placenta"	151374
# "impending"	151371
# "practitioners"	151281
# "realms"	151280
# "sadness"	151260
# "ashore"	151242
# "unconstitutional"	151234
# "jane"	151227
# "flexor"	151201
# "fairness"	151201
# "scholarly"	151198
# "nuisance"	151165
# "humidity"	151142
# "switzerland"	151079
# "adversely"	151078
# "feathers"	151006
# "pleas"	150994
# "inauguration"	150960
# "offend"	150922
# "superstition"	150891
# "tents"	150863
# "universality"	150841
# "logarithm"	150747
# "conveying"	150741
# "preside"	150675
# "unchanged"	150654
# "clues"	150630
# "shy"	150556
# "secrecy"	150526
# "hymn"	150448
# "metropolis"	150403
# "captains"	150346
# "polished"	150340
# "formative"	150290
# "purport"	150287
# "lobby"	150286
# "secreted"	150283
# "probe"	150280
# "drained"	150272
# "worldly"	150265
# "examines"	150254
# "twist"	150180
# "prosecuted"	150152
# "imf"	150136
# "inspector"	150098
# "alpha"	150080
# "environments"	150047
# "sensibility"	150023
# "believers"	149889
# "demonstrating"	149866
# "deduce"	149839
# "congestive"	149833
# "dame"	149819
# "groove"	149806
# "instructor"	149798
# "marking"	149792
# "postoperative"	149784
# "defenders"	149704
# "contamination"	149593
# "whip"	149567
# "pierced"	149518
# "transplantation"	149494
# "shoe"	149379
# "recreation"	149322
# "vastly"	149315
# "illusions"	149307
# "backwards"	149296
# "poorly"	149289
# "forfeited"	149252
# "softly"	149245
# "arches"	149234
# "apartments"	149188
# "sticking"	149165
# "emblem"	149109
# "gratify"	149077
# "efficiently"	148993
# "plentiful"	148967
# "shells"	148829
# "counseling"	148824
# "necks"	148730
# "acknowledgments"	148699
# "magnificence"	148694
# "graces"	148689
# "enforcing"	148688
# "regeneration"	148654
# "mobilization"	148643
# "codes"	148541
# "maxillary"	148523
# "painters"	148512
# "dilatation"	148506
# "metaphysical"	148472
# "imbued"	148407
# "pipes"	148340
# "defender"	148300
# "thinkers"	148291
# "cognizance"	148283
# "disposing"	148258
# "mind's"	148233
# "overcoming"	148165
# "endeavouring"	148143
# "cunning"	148096
# "impair"	148079
# "testified"	148071
# "dementia"	148069
# "bottles"	148064
# "southeastern"	148050
# "resolving"	148024
# "gaza"	147988
# "narrower"	147969
# "humane"	147920
# "priesthood"	147903
# "parks"	147889
# "aggravated"	147856
# "continuously"	147837
# "terminology"	147830
# "favorably"	147789
# "ce"	147755
# "substantive"	147746
# "learner"	147594
# "flourishing"	147557
# "rating"	147526
# "ills"	147457
# "beset"	147453
# "polymer"	147422
# "knocking"	147394
# "bacon"	147380
# "penetrating"	147345
# "axe"	147295
# "kindred"	147274
# "incur"	147260
# "da"	147231
# "crucified"	147213
# "gravel"	147142
# "sheath"	147129
# "viceroy"	147099
# "attested"	147072
# "demographic"	147052
# "eliminating"	147048
# "thereon"	147010
# "assemblies"	147008
# "iran"	147005
# "singapore"	146918
# "occurrences"	146877
# "predicting"	146861
# "electorate"	146822
# "barred"	146821
# "postpone"	146808
# "sequel"	146804
# "darker"	146781
# "rudiments"	146779
# "schizophrenia"	146741
# "est"	146713
# "hay"	146673
# "liverpool"	146663
# "purified"	146561
# "counteract"	146493
# "eagle"	146480
# "sunny"	146460
# "darkest"	146323
# "dishes"	146274
# "knelt"	146221
# "inventor"	146210
# "diplomacy"	146167
# "cane"	146155
# "awaiting"	146152
# "brunt"	146071
# "enumerated"	146027
# "authoritative"	146017
# "soundness"	145987
# "peru"	145983
# "consonant"	145913
# "spherical"	145887
# "opium"	145865
# "jar"	145849
# "imagery"	145821
# "intolerable"	145815
# "entitle"	145750
# "defines"	145702
# "percentages"	145698
# "commensurate"	145688
# "parallels"	145674
# "governance"	145658
# "loosely"	145651
# "denies"	145624
# "streaming"	145605
# "backing"	145553
# "backbone"	145527
# "anglican"	145511
# "disparity"	145499
# "calamity"	145441
# "suspicions"	145375
# "labourers"	145373
# "ieee"	145348
# "frustrated"	145333
# "accompaniment"	145279
# "intricate"	145248
# "pernicious"	145247
# "belgium"	145155
# "entities"	145104
# "diamond"	145100
# "wept"	145070
# "stack"	145040
# "imperfections"	144999
# "delivering"	144955
# "questionable"	144954
# "terminals"	144945
# "concede"	144922
# "trigger"	144908
# "synonymous"	144867
# "flatter"	144861
# "leaped"	144846
# "halfway"	144790
# "tourism"	144753
# "puzzle"	144721
# "predecessor"	144647
# "contending"	144569
# "modernization"	144564
# "atrophy"	144548
# "restructuring"	144482
# "unnatural"	144472
# "annoyed"	144470
# "copying"	144468
# "broadest"	144415
# "fog"	144370
# "coating"	144342
# "durable"	144323
# "desperately"	144273
# "blocked"	144235
# "elegance"	144221
# "economists"	144192
# "strenuous"	144187
# "secretaries"	144174
# "statues"	144112
# "bulb"	144065
# "comic"	144047
# "acutely"	143953
# "fuss"	143927
# "chord"	143860
# "captivity"	143858
# "travellers"	143847
# "uppermost"	143805
# "despise"	143734
# "babies"	143731
# "frost"	143717
# "countess"	143672
# "relic"	143652
# "vietnamese"	143643
# "pleases"	143629
# "ovary"	143615
# "consultant"	143593
# "viral"	143576
# "woven"	143459
# "clergyman"	143407
# "madras"	143391
# "inquisition"	143388
# "steering"	143376
# "canons"	143375
# "battalion"	143369
# "socioeconomic"	143361
# "ship's"	143357
# "staple"	143354
# "precincts"	143324
# "dissociation"	143281
# "arduous"	143199
# "glowing"	143176
# "hampered"	143142
# "synagogue"	143106
# "matthew"	143098
# "realizes"	143081
# "marshall"	143059
# "crystalline"	143040
# "linguistics"	143038
# "anesthesia"	143004
# "practise"	142912
# "horseback"	142818
# "summon"	142803
# "herds"	142798
# "eruption"	142783
# "restrictive"	142780
# "specialist"	142763
# "plexus"	142689
# "precarious"	142681
# "athenians"	142667
# "rejoiced"	142654
# "precursor"	142625
# "sticks"	142568
# "vigilance"	142541
# "provoke"	142518
# "accent"	142508
# "recipients"	142500
# "actuated"	142486
# "viewing"	142462
# "merciful"	142453
# "authorship"	142448
# "mystical"	142447
# "abyss"	142437
# "turmoil"	142428
# "subcutaneous"	142382
# "radioactive"	142368
# "insensible"	142243
# "nationals"	142149
# "appropriateness"	142113
# "spelling"	142098
# "repression"	142095
# "alzheimer's"	142085
# "violently"	142069
# "marrying"	142067
# "pursuits"	142039
# "tray"	142032
# "scrap"	142028
# "concur"	141984
# "sinners"	141936
# "trademark"	141926
# "fulfilling"	141919
# "milton"	141908
# "factions"	141903
# "southward"	141896
# "arabian"	141878
# "avenge"	141840
# "controversies"	141834
# "uniqueness"	141818
# "miraculous"	141802
# "sanctioned"	141761
# "mutations"	141756
# "extravagant"	141752
# "permitting"	141749
# "distributions"	141704
# "anemia"	141669
# "transparent"	141576
# "conditional"	141575
# "polarization"	141571
# "shrewd"	141510
# "antiquities"	141439
# "highways"	141423
# "delights"	141415
# "lighting"	141403
# "relies"	141382
# "surround"	141366
# "experimentally"	141346
# "ferdinand"	141339
# "potentials"	141331
# "reprint"	141330
# "harmonious"	141328
# "thoughtful"	141321
# "hymns"	141227
# "replacing"	141197
# "incubation"	141145
# "enumeration"	141070
# "appointments"	141067
# "notification"	141051
# "warmer"	141005
# "avert"	140973
# "autobiography"	140944
# "nationalist"	140942
# "subsidiary"	140836
# "accepts"	140802
# "lamps"	140793
# "plaintiffs"	140762
# "atrium"	140759
# "articular"	140728
# "deliberations"	140721
# "postulated"	140705
# "housed"	140683
# "esophagus"	140673
# "frankly"	140616
# "preparatory"	140605
# "anarchy"	140576
# "campaigns"	140574
# "distracted"	140543
# "testator"	140496
# "troublesome"	140437
# "dryness"	140413
# "binds"	140398
# "fide"	140358
# "orient"	140346
# "indiana"	140336
# "predominance"	140334
# "forcibly"	140303
# "allude"	140282
# "vomiting"	140239
# "cheese"	140235
# "traversed"	140187
# "interrupt"	140174
# "workplace"	140133
# "armistice"	140086
# "merged"	140083
# "qui"	140029
# "canals"	140002
# "nursery"	139999
# "illustrating"	139964
# "domains"	139933
# "trembled"	139766
# "murderer"	139732
# "fibrous"	139659
# "usages"	139639
# "unrelated"	139637
# "freshness"	139570
# "interim"	139562
# "glasgow"	139537
# "henceforth"	139531
# "displeasure"	139511
# "douglas"	139478
# "neighbour"	139475
# "administering"	139447
# "clubs"	139409
# "downs"	139401
# "martyrs"	139375
# "politic"	139346
# "humiliation"	139256
# "whigs"	139236
# "arkansas"	139209
# "appellate"	139167
# "broadcasting"	139141
# "traders"	139077
# "ulnar"	139017
# "turbulent"	138963
# "accrue"	138937
# "uric"	138935
# "odor"	138869
# "grandson"	138811
# "establishments"	138764
# "metallic"	138734
# "predicate"	138715
# "amuse"	138683
# "twisted"	138670
# "movies"	138666
# "confided"	138643
# "ganglion"	138618
# "oaths"	138599
# "sherman"	138594
# "dysfunction"	138588
# "provoked"	138585
# "asserts"	138581
# "uptake"	138564
# "alternating"	138520
# "attaches"	138510
# "syntax"	138455
# "transcription"	138443
# "simplify"	138432
# "sayings"	138427
# "targets"	138421
# "intrusion"	138407
# "bees"	138387
# "discomfort"	138372
# "insists"	138371
# "lutheran"	138321
# "tribal"	138289
# "hebrews"	138272
# "inspect"	138265
# "terrors"	138162
# "diabetic"	138149
# "recruited"	138124
# "individually"	138104
# "dietary"	138089
# "constancy"	137935
# "lag"	137811
# "solemnity"	137796
# "masculine"	137779
# "undergraduate"	137714
# "relinquish"	137662
# "dividend"	137592
# "numerator"	137561
# "survivor"	137546
# "carpet"	137543
# "despatch"	137520
# "remotest"	137491
# "executor"	137485
# "drafted"	137479
# "sac"	137467
# "trademarks"	137430
# "weakest"	137393
# "explanatory"	137390
# "randomly"	137372
# "disproportionate"	137295
# "extant"	137282
# "confuse"	137225
# "skins"	137211
# "faded"	137180
# "kin"	137158
# "crowns"	137099
# "purchases"	137087
# "articulate"	137062
# "illuminated"	137053
# "laden"	137035
# "performances"	136995
# "comprehended"	136955
# "hangs"	136952
# "despised"	136909
# "commissions"	136900
# "sandy"	136871
# "weighing"	136796
# "au"	136773
# "barren"	136703
# "superfluous"	136700
# "excitation"	136695
# "believeth"	136682
# "bounty"	136682
# "amplifier"	136597
# "prolong"	136584
# "fortified"	136560
# "lodging"	136556
# "hydroxide"	136545
# "falsehood"	136536
# "ammonium"	136534
# "remembering"	136499
# "immigrant"	136497
# "consuming"	136481
# "kashmir"	136479

# %% [markdown]
# ## Stripes

# %%
# %%writefile stripes5_5.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import re
import mrjob
import json
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import itertools
import collections
import time
import logging

class stripes(MRJob):
  
    #START SUDENT CODE531_STRIPES
  
    MRJob.SORT_VALUES = True
    
    def __init__(self, args):
        self.valid_words = set()
        super(stripes, self).__init__(args)
    
    def mapper_init(self):
        # Load the left table in the init so all mappers get this info
        with open("frequencies5.5", 'r') as f:
            for line in f.readlines():
                x = line.strip().split("\t")
                self.valid_words.add(x[0].strip("\""))
            
    
    def mapper(self, _, line):
        splits = line.rstrip("\n").split("\t")

        words = splits[0].lower().split()
        count = splits[1]

        H = {}
        for subset in itertools.combinations(sorted(set(words)), 2):
            
            # Logic from slack discussion, with Sharmila and Kyle: the stripes are assymentric
            # If a given word is a valid word, then we build a stripe for the other word and add
            # its co-ocurrence to the valid word. If both words are valid, only then we add
            # to stripes in a symmetric way
            
            if subset[1] in self.valid_words:

                # Process combinations in sorted order, i.e. "hello","tomorrow"
                if subset[0] not in H.keys():
                    H[subset[0]] = {}
                    H[subset[0]][subset[1]] = count 
                elif subset[1] not in H[subset[0]]:
                    H[subset[0]][subset[1]] = count
                else:
                    H[subset[0]][subset[1]] += count

            if subset[0] in self.valid_words:
                # Obtain combinations in reverse order
                if subset[1] not in H.keys():
                    H[subset[1]] = {}
                    H[subset[1]][subset[0]] = count 
                elif subset[0] not in H[subset[1]]:
                    H[subset[1]][subset[0]] = count
                else:
                    H[subset[1]][subset[0]] += count
                    
        for key in H.keys():
            yield key, H[key]

    def reducer(self, key, values):
        
        counter = {}

        for value in values:
            
            for k, v in value.iteritems():
                if k in counter:
                    counter[k] += int(v)
                else:
                    counter[k] = int(v)
        
        yield key, counter

  #END SUDENT CODE531_STRIPES
  
if __name__ == '__main__':
    start_time = time.time()
    stripes.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting stripes5_5.py

# %%
# !hdfs dfs -rm -r stripes5.5
# !python stripes5_5.py --file frequencies5.5 -r hadoop hdfs:///user/cendylin/filtered-5Grams/ \
    --archive={pyArchive} \
    > stripes5.5
# Out:
# rm: `stripes5.5': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/stripes5_5.chqngh.20170620.064052.484116
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/stripes5_5.chqngh.20170620.064052.484116/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob2001253581521412151.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 190
#   number of splits:190
#   Submitting tokens for job: job_1497906899862_0400
#   Submitted application application_1497906899862_0400
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0400/
#   Running job: job_1497906899862_0400
#   Job job_1497906899862_0400 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 9% reduce 0%
#    map 11% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 16% reduce 0%
#    map 17% reduce 0%
#    map 19% reduce 0%
#    map 21% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 26% reduce 0%
#    map 28% reduce 0%
#    map 31% reduce 0%
#    map 33% reduce 0%
#    map 36% reduce 0%
#    map 39% reduce 0%
#    map 42% reduce 0%
#    map 46% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 56% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 65% reduce 0%
#    map 67% reduce 0%
#    map 70% reduce 0%
#    map 71% reduce 0%
#    map 74% reduce 0%
#    map 78% reduce 0%
#    map 83% reduce 0%
#    map 86% reduce 0%
#    map 89% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 67%
#    map 100% reduce 68%
#    map 100% reduce 69%
#    map 100% reduce 70%
#    map 100% reduce 71%
#    map 100% reduce 72%
#    map 100% reduce 73%
#    map 100% reduce 74%
#    map 100% reduce 75%
#    map 100% reduce 76%
#    map 100% reduce 77%
#    map 100% reduce 78%
#    map 100% reduce 79%
#    map 100% reduce 80%
#    map 100% reduce 81%
#    map 100% reduce 82%
#    map 100% reduce 83%
#    map 100% reduce 84%
#    map 100% reduce 85%
#    map 100% reduce 86%
#    map 100% reduce 87%
#    map 100% reduce 88%
#    map 100% reduce 89%
#    map 100% reduce 90%
#    map 100% reduce 91%
#    map 100% reduce 92%
#    map 100% reduce 93%
#    map 100% reduce 94%
#    map 100% reduce 95%
#    map 100% reduce 96%
#    map 100% reduce 97%
#    map 100% reduce 98%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497906899862_0400 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/stripes5_5.chqngh.20170620.064052.484116/output
# Counters: 51
# 	File Input Format Counters
# 		Bytes Read=2156069116
# 	File Output Format Counters
# 		Bytes Written=13615916
# 	File System Counters
# 		FILE: Number of bytes read=28013587
# 		FILE: Number of bytes written=110000419
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2156101116
# 		HDFS: Number of bytes written=13615916
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=573
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=3
# 		Launched map tasks=193
# 		Launched reduce tasks=1
# 		Other local map tasks=2
# 		Rack-local map tasks=191
# 		Total megabyte-milliseconds taken by all map tasks=9429204480
# 		Total megabyte-milliseconds taken by all reduce tasks=428254720
# 		Total time spent by all map tasks (ms)=6138805
# 		Total time spent by all maps in occupied slots (ms)=18416415
# 		Total time spent by all reduce tasks (ms)=167287
# 		Total time spent by all reduces in occupied slots (ms)=836435
# 		Total vcore-milliseconds taken by all map tasks=6138805
# 		Total vcore-milliseconds taken by all reduce tasks=167287
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1719120
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=45952
# 		Input split bytes=32000
# 		Map input records=58682266
# 		Map output bytes=140832565
# 		Map output materialized bytes=56527081
# 		Map output records=5141537
# 		Merged Map outputs=190
# 		Physical memory (bytes) snapshot=154455183360
# 		Reduce input groups=3422340
# 		Reduce input records=5141537
# 		Reduce output records=57934
# 		Reduce shuffle bytes=56527081
# 		Shuffled Maps =190
# 		Spilled Records=10283074
# 		Total committed heap usage (bytes)=299931533312
# 		Virtual memory (bytes) snapshot=421354229760
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/stripes5_5.chqngh.20170620.064052.484116/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/stripes5_5.chqngh.20170620.064052.484116...
# Removing temp directory /tmp/stripes5_5.chqngh.20170620.064052.484116...
# WARNING:root:Elapsed time: 337.288557053 seconds
#     In minutes: 5.62147595088 mins

# %% [markdown]
# ### Frequencies 5_5 on Full Set Statistics:
#
# #### Time
# * _Run time: 574.02 seconds_
#
# * _Run time: 9.57 minutes_
#
# #### Input/Output statistics
# * _Bytes Read: 4176522_
#
# * _Bytes Written: 17944_
#
# #### Cluster Resources
# * _Number of Mappers: 2_
124, "rabbit": 48910, "rivalry": 15814, "cunning": 20932, "logarithm": 16684, "preponderance": 77844, "err": 1026, "fortified": 32772, "insists": 7225, "dew": 10863, "movies": 6363, "arches": 8702, "deficiencies": 4249, "xiv": 2744, "executor": 5435, "ribs": 11083, "misfortunes": 7198, "spy": 93101, "crazy": 30626, "psychoanalytic": 7892, "viceroy": 7225, "serpent": 46388, "shepherd": 41258, "numerator": 3310, "hebrews": 2746, "acetic": 10101, "impair": 5181, "sued": 10754, "surround": 11202, "pyramid": 36254, "flexor": 1922, "counseling": 10961, "rods": 34433, "provoke": 38830, "peritoneal": 2201, "pink": 43998, "autobiography": 23684, "compounded": 16123, "defective": 26163, "prussian": 9511, "alzheimer's": 8884, "negation": 37331, "hampered": 17852, "glowing": 35946, "buenos": 4280, "suspend": 8560, "vigilance": 6683, "ferdinand": 2756, "ulnar": 951, "classify": 9456, "fare": 7765, "designer": ...
# "a's"	{"marking": 53, "labourers": 53}
# "aa"	{"frost": 333, "jackson": 43}
# "aaa"	{"rating": 188, "unconstitutional": 106}
# "aarhus"	{"denmark": 422}
# "aaron"	{"diamond": 291, "thereon": 71, "confidential": 84, "commissions": 41, "douglas": 252, "priesthood": 797, "inherit": 92, "atonement": 129, "pitched": 59, "spake": 1080, "woven": 48, "afterward": 170, "rods": 288}
# "aaron's"	{"serpent": 115}
# "aaronic"	{"priesthood": 401}
# "ab"	{"sterling": 62, "conveying": 273, "chord": 1006, "spectators": 89, "hoc": 94, "subscribed": 44, "residential": 77, "consul": 48, "amplifier": 91, "ce": 58, "terminals": 141, "est": 256, "wires": 51, "qui": 1445, "lever": 77, "honors": 43, "parallels": 89}
# "aba"	{"canons": 80}

# %% [markdown]
# ## Inverted Index

# %%
# %%writefile index5_5.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-


from __future__ import division
import collections
import re
import json
import math
import itertools
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import json
import time
import logging

class index(MRJob):
    
    #START SUDENT CODE531_INV_INDEX
  
    def mapper(self, _, line):
        key, stripeJson = line.strip().split('\t')
        key = key.strip("\"")
        stripe = json.loads(stripeJson)
        
        for k, v in stripe.iteritems():
            yield k, [key, len(stripe)]
        
    def reducer(self, key, values):

        table = {}
        for value in values:
            table[value[0]] = value[1]
            
        yield key, table
        
    #END SUDENT CODE531_INV_INDEX
        
if __name__ == '__main__':
    start_time = time.time()
    index.run() 
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting index5_5.py

# %%
# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 \
    --archive={pyArchive} \
    > index5.5
# Out:
# rm: `index5.5': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/index5_5.chqngh.20170620.064714.193142
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/index5_5.chqngh.20170620.064714.193142/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob3872218187539851377.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_0402
#   Submitted application application_1497906899862_0402
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_0402/
#   Running job: job_1497906899862_0402
#   Job job_1497906899862_0402 running in uber mode : false
#    map 0% reduce 0%
#    map 29% reduce 0%
#    map 45% reduce 0%
#    map 61% reduce 0%
#    map 80% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 72%
#    map 100% reduce 75%
#    map 100% reduce 79%
#    map 100% reduce 82%
#    map 100% reduce 85%
#    map 100% reduce 89%
#    map 100% reduce 93%
#    map 100% reduce 96%
#    map 100% reduce 100%
#   Job job_1497906899862_0402 completed successfully
#   Output directory: hdfs:///user/chqngh/tmp/mrjob/index5_5.chqngh.20170620.064714.193142/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=13623702
# 	File Output Format Counters
# 		Bytes Written=11622508
# 	File System Counters
# 		FILE: Number of bytes read=8882141
# 		FILE: Number of bytes written=17930806
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=13624032
# 		HDFS: Number of bytes written=11622508
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=58841088
# 		Total megabyte-milliseconds taken by all reduce tasks=86461440
# 		Total time spent by all map tasks (ms)=38308
# 		Total time spent by all maps in occupied slots (ms)=114924
# 		Total time spent by all reduce tasks (ms)=33774
# 		Total time spent by all reduces in occupied slots (ms)=168870
# 		Total vcore-milliseconds taken by all map tasks=38308
# 		Total vcore-milliseconds taken by all reduce tasks=33774
# 	Map-Reduce Framework
# 		CPU time spent (ms)=60810
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=85
# 		Input split bytes=330
# 		Map input records=57934
# 		Map output bytes=20930479
# 		Map output materialized bytes=8651553
# 		Map output records=783529
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1900642304
# 		Reduce input groups=1000
# 		Reduce input records=783529
# 		Reduce output records=1000
# 		Reduce shuffle bytes=8651553
# 		Shuffled Maps =2
# 		Spilled Records=1567058
# 		Total committed heap usage (bytes)=5203034112
# 		Virtual memory (bytes) snapshot=7740833792
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/chqngh/tmp/mrjob/index5_5.chqngh.20170620.064714.193142/output...
# Removing HDFS temp directory hdfs:///user/chqngh/tmp/mrjob/index5_5.chqngh.20170620.064714.193142...
# Removing temp directory /tmp/index5_5.chqngh.20170620.064714.193142...
# WARNING:root:Elapsed time: 99.45480299 seconds
#     In minutes: 1.65758004983 mins

# %% [markdown]
# ### Index 5_5 on Stripes5.5 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
# !head index5.5
# Out:
# "abnormalities"	{"urinary": 24, "all": 942, "pigmentosum": 4, "lymphatic": 13, "skeleton": 18, "limited": 180, "from": 991, "caused": 218, "resistance": 109, "by": 998, "leads": 118, "mild": 54, "systemic": 20, "sleep": 87, "asymptomatic": 5, "skin": 125, "extremities": 26, "disk": 14, "children": 334, "causes": 201, "increase": 224, "disorders": 62, "physiological": 22, "white": 311, "disability": 13, "young": 354, "parenchyma": 5, "to": 1000, "those": 861, "rhythm": 35, "monoamine": 3, "include": 119, "presentation": 44, "as": 999, "leukocytes": 10, "subgenual": 1, "hormone": 31, "androgen": 7, "risk": 165, "radiologic": 1, "iliac": 6, "regional": 60, "angiographically": 1, "fat": 58, "pigment": 6, "alcoholics": 4, "hindered": 15, "affect": 90, "capillary": 15, "swallowing": 9, "neurological": 10, "respiratory": 32, "intervertebral": 6, "level": 281, "skeletal": 23, "shock": 61, "postural": 2, "mucosal": 9, "small": 507, "noted": 86, "gallbladder": 4, "upper": 204, "lysosomal": 7, "occurrence": 61, "findings": 39, "infancy": 33, "plexus": 10, "cytomegalovirus": 5, "cavus": 1, "rate": 213, "lymphoblastic": 4, "prefrontal": 6, "functioning": 31, "even": 646, "established": 184, "gonad": 2, "adjustment": 49, "appear": 328, "incompatible": 21, "disease": 160, "hematologic": 3, "hereditary": 50, "cell": 138, "above": 342, "new": 757, "exercise": 160, "body": 448, "toes": 16, "behavior": 143, "extraskeletal": 1, "exchange": 124, "water": 319, "reported": 131, "corneum": 1, "active": 147, "physi
113, "ideas": 179, "note": 148, "also": 773, "hearty": 23, "take": 559, "organizations": 49, "xi": 7, "shall": 583, "quote": 17, "measures": 145, "intentions": 47, "printed": 57, "preliminary": 33, "accepting": 18, "america": 193, "extremely": 103, "fervent": 17, "grave": 111, "especially": 165, "professor": 46, "corwin": 2, "mrs": 41, "incomplete": 16, "joining": 20, "particularly": 139, "supported": 120, "chapters": 46, "utter": 51, "pleased": 78, "staff": 73, "completion": 60, "partially": 53, "based": 256, "copyright": 25, "title": 127, " ...

# %% [markdown]
# ## Similarity

# %%
# %%writefile similarity5_5.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import collections
import re
import json
import math
#import numpy as np
import itertools
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import time
import logging

class similarity(MRJob):
  
    #START SUDENT CODE531_SIMILARITY

    MRJob.SORT_VALUES = True
    
    def mapper(self, _, line):
        key, valuesJson = line.strip().split('\t')
        key = key.strip("\"")
        values = json.loads(valuesJson)

        for pair in itertools.combinations(sorted(set(values)), 2):
            yield pair, [values[pair[0]], values[pair[1]]]
        
    def reducer(self, key, values):
        intersection = 0
        count1 = None
        count2 = None
        
        cosine = 0.0
        
        # Iterate through the values
        for value in values:
            # Jaccard, get counts for the intersection, and for each set
            intersection += 1
            if count1 == None:
                count1 = value[0]
                count2 = value[1]
        
            # Cosine
            a = 1 / math.sqrt(value[0])
            b = 1 / math.sqrt(value[1])
            cosine += a * b
            
        jaccard = float(intersection) / float(count1 + count2 - intersection)
        
        overlap_coefficient = float(intersection) / min(count1, count2)
        
        dice_coefficient = float(2 * intersection) / (count1 + count2)
        
        average = (cosine + jaccard + overlap_coefficient + dice_coefficient) / 4.0
        
        yield average, [key[0] + ' - ' + key[1], cosine, jaccard, overlap_coefficient, dice_coefficient, average]
    
    
    def max_reducer(self, average, records):
        for record in records:
            yield average, record

    def steps(self):
        
        custom_jobconf = {
            'stream.num.map.output.key.fields':'2',
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-k1,1nr',
            'mapred.reduce.tasks': '1'
        }

        return [
                MRStep(mapper=self.mapper,
                    reducer=self.reducer),
                MRStep(jobconf=custom_jobconf,
                       reducer=self.max_reducer)
                 ]
    
    #END SUDENT CODE531_SIMILARITY
  
if __name__ == '__main__':
    start_time = time.time()
    similarity.run()
    elapsed_time = time.time() - start_time
    mins = elapsed_time/float(60)
    a = """Elapsed time: %s seconds
    In minutes: %s mins""" % (str(elapsed_time), str(mins))
    logging.warning(a)
# Out:
# Overwriting similarity5_5.py

# %%
# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --archive={pyArchive} \
    > similarity5.5
# Out:
# rm: `similarity5.5': No such file or directory
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/similarity5_5.chqngh.20170620.084116.036635
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/chqngh/tmp/mrjob/similarity5_5.chqngh.20170620.084116.036635/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
# ^C
# Traceback (most recent call last):
#   File "similarity5_5.py", line 87, in <module>
#     similarity.run()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/job.py", line 429, in run
#     mr_job.execute()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/job.py", line 447, in execute
#     super(MRJob, self).execute()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/launch.py", line 158, in execute
#     self.run_job()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/launch.py", line 228, in run_job
#     runner.run()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/runner.py", line 481, in run
#     self._run()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/hadoop.py", line 336, in _run
#     self._run_job_in_hadoop()
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/hadoop.py", line 435, in _run_job_in_hadoop
#     record_callback=_log_record_from_hadoop))
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/logs/step.py", line 224, in _interpret_hadoop_jar_command_stderr
#     result = _parse_step_syslog_from_log4j_records(yield_records())
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/logs/step.py", line 265, in _parse_step_syslog_from_log4j_records
#     for record in records:
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/logs/step.py", line 219, in yield_records
#     pre_filter=pre_filter):
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/logs/log4j.py", line 67, in _parse_hadoop_log4j_records
#     for line_num, line in enumerate(lines):
#   File "/home/chqngh/.conda/envs/py27/lib/python2.7/site-packages/mrjob/logs/step.py", line 205, in yield_lines
#     for line in stderr:
# KeyboardInterrupt

# %% [markdown]
# ### Similarity 5_5 on Index 5.5 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
# !head similarity5.5

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims
# Out:
# mkdir: cannot create directory `sims2': File exists

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/chqngh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# END STUDENT CODE 5.5

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )
# Out:
# Top/Bottom 20 results - Similarity measures - sorted by cosine
# (From the entire data set)
# —————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#                           pair |         cosine |        jaccard |        overlap |           dice |        average
# ---------------------------------------------------------------------------------------------------------------------
# —————————————————————————————————————————————————————————————————————————————————————————————————————————————————————

# %%
Top/Bottom 20 results - Similarity measures - sorted by cosine
(From the entire data set)
—————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
                          pair |         cosine |        jaccard |        overlap |           dice |        average
---------------------------------------------------------------------------------------------------------------------
                   cons - pros |       0.894427 |       0.800000 |       1.000000 |       0.888889 |       0.895829
            forties - twenties |       0.816497 |       0.666667 |       1.000000 |       0.800000 |       0.820791
                    own - time |       0.809510 |       0.670563 |       0.921168 |       0.802799 |       0.801010
                 little - time |       0.784197 |       0.630621 |       0.926101 |       0.773473 |       0.778598
                  found - time |       0.783434 |       0.636364 |       0.883788 |       0.777778 |       0.770341
                 nova - scotia |       0.774597 |       0.600000 |       1.000000 |       0.750000 |       0.781149
                   hong - kong |       0.769800 |       0.615385 |       0.888889 |       0.761905 |       0.758995
                   life - time |       0.769666 |       0.608789 |       0.925081 |       0.756829 |       0.765091
                  time - world |       0.755476 |       0.585049 |       0.937500 |       0.738209 |       0.754058
                  means - time |       0.752181 |       0.587117 |       0.902597 |       0.739854 |       0.745437
                   form - time |       0.749943 |       0.588418 |       0.876733 |       0.740885 |       0.738995
       infarction - myocardial |       0.748331 |       0.560000 |       1.000000 |       0.717949 |       0.756570
                 people - time |       0.745788 |       0.573577 |       0.923875 |       0.729010 |       0.743063
                 angeles - los |       0.745499 |       0.586207 |       0.850000 |       0.739130 |       0.730209
                  little - own |       0.739343 |       0.585834 |       0.767296 |       0.738834 |       0.707827
                    life - own |       0.737053 |       0.582217 |       0.778502 |       0.735951 |       0.708430
          anterior - posterior |       0.733388 |       0.576471 |       0.790323 |       0.731343 |       0.707881
                  power - time |       0.719611 |       0.533623 |       0.933586 |       0.695898 |       0.720680
              dearly - install |       0.707107 |       0.500000 |       1.000000 |       0.666667 |       0.718443
                   found - own |       0.704802 |       0.544134 |       0.710949 |       0.704776 |       0.666165
—————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
           arrival - essential |       0.008258 |       0.004098 |       0.009615 |       0.008163 |       0.007534
         governments - surface |       0.008251 |       0.003534 |       0.014706 |       0.007042 |       0.008383
                king - lesions |       0.008178 |       0.003106 |       0.017857 |       0.006192 |       0.008833
              clinical - stood |       0.008178 |       0.003831 |       0.011905 |       0.007634 |       0.007887
               till - validity |       0.008172 |       0.003367 |       0.015625 |       0.006711 |       0.008469
            evidence - started |       0.008159 |       0.003802 |       0.012048 |       0.007576 |       0.007896
               forces - record |       0.008152 |       0.003876 |       0.011364 |       0.007722 |       0.007778
               primary - stone |       0.008146 |       0.004065 |       0.009091 |       0.008097 |       0.007350
             beneath - federal |       0.008134 |       0.004082 |       0.008403 |       0.008130 |       0.007187
                factors - rose |       0.008113 |       0.004032 |       0.009346 |       0.008032 |       0.007381
           evening - functions |       0.008069 |       0.004049 |       0.008333 |       0.008065 |       0.007129
                   bone - told |       0.008061 |       0.003704 |       0.012346 |       0.007380 |       0.007873
             building - occurs |       0.008002 |       0.003891 |       0.010309 |       0.007752 |       0.007489
                 company - fig |       0.007913 |       0.003257 |       0.015152 |       0.006494 |       0.008204
               chronic - north |       0.007803 |       0.003268 |       0.014493 |       0.006515 |       0.008020
             evaluation - king |       0.007650 |       0.003030 |       0.015625 |       0.006042 |       0.008087
             resulting - stood |       0.007650 |       0.003663 |       0.010417 |       0.007299 |       0.007257
                 agent - round |       0.007515 |       0.003289 |       0.012821 |       0.006557 |       0.007546
         afterwards - analysis |       0.007387 |       0.003521 |       0.010204 |       0.007018 |       0.007032
            posterior - spirit |       0.007156 |       0.002660 |       0.016129 |       0.005305 |       0.007812

# %% [markdown]
# ## 3.  HW5.6  <a name="5.6"></a> Evaluation of synonyms that your discovered
# [Back to Table of Contents](#TOC)
#
#
# In this part of the assignment you will evaluate the success of you synonym detector (developed in response to HW5.4).
# Take the top 1,000 closest/most similar/correlative pairs of words as determined by your measure in HW5.4, and use the synonyms function in the accompanying python code:
#
# nltk_synonyms.py
#
# Note: This will require installing the python nltk package:
#
# http://www.nltk.org/install.html
#
# and downloading its data with nltk.download().
#
# For each (word1,word2) pair, check to see if word1 is in the list,
# synonyms(word2), and vice-versa. If one of the two is a synonym of the other,
# then consider this pair a 'hit', and then report the precision, recall, and F1 measure  of
# your detector across your 1,000 best guesses. Report the macro averages of these measures.

# %% [markdown]
# ### Calculate performance measures:
# $$Precision (P) = \frac{TP}{TP + FP} $$
# $$Recall (R) = \frac{TP}{TP + FN} $$
# $$F1 = \frac{2 * ( precision * recall )}{precision + recall}$$
#
#
# We calculate Precision by counting the number of hits and dividing by the number of occurances in our top1000 (opportunities)
# We calculate Recall by counting the number of hits, and dividing by the number of synonyms in wordnet (syns)
#
#
# Other diagnostic measures not implemented here:  https://en.wikipedia.org/wiki/F1_score#Diagnostic_Testing

# %%
''' Performance measures '''
from __future__ import division
import numpy as np
import json
import nltk
from nltk.corpus import wordnet as wn
import sys
import time
import logging

#print all the synset element of an element
def synonyms(string):
    syndict = {}
    for i,j in enumerate(wn.synsets(string)):
        syns = j.lemma_names()
        for syn in syns:
            syndict.setdefault(syn,1)
    return syndict.keys()
hits = []

TP = 0
FP = 0

TOTAL = 0
flag = False # so we don't double count, but at the same time don't miss hits
start_time = time.time()
top1000sims = []
with open("sims2/top1000sims","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        top1000sims.append(lisst)
    

measures = {}
not_in_wordnet = []

for line in top1000sims:
    TOTAL += 1

    pair = line[0]
    words = pair.split(" - ")
    
    for word in words:
        if word not in measures:
            measures[word] = {"syns":0,"opps": 0,"hits":0}
        measures[word]["opps"] += 1 
    
    syns0 = synonyms(words[0])
    measures[words[1]]["syns"] = len(syns0)
    if len(syns0) == 0:
        not_in_wordnet.append(words[0])
        
    if words[1] in syns0:
        TP += 1
        hits.append(line)
        flag = True
        measures[words[1]]["hits"] += 1
        
        
        
    syns1 = synonyms(words[1]) 
    measures[words[0]]["syns"] = len(syns1)
    if len(syns1) == 0:
        not_in_wordnet.append(words[1])

    if words[0] in syns1:
        if flag == False:
            TP += 1
            hits.append(line)
            measures[words[0]]["hits"] += 1
            
    flag = False    

precision = []
recall = []
f1 = []

for key in measures:
    p,r,f = 0,0,0
    if measures[key]["hits"] > 0 and measures[key]["syns"] > 0:
        p = measures[key]["hits"]/measures[key]["opps"]
        r = measures[key]["hits"]/measures[key]["syns"]
        f = 2 * (p*r)/(p+r)
    
    # For calculating measures, only take into account words that have synonyms in wordnet
    if measures[key]["syns"] > 0:
        precision.append(p)
        recall.append(r)
        f1.append(f)

    
# Take the mean of each measure    
print "—"*110    
print "Number of Hits:",TP, "out of top",TOTAL
print "Number of words without synonyms:",len(not_in_wordnet)
print "—"*110 
print "Precision\t", np.mean(precision)
print "Recall\t\t", np.mean(recall)
print "F1\t\t", np.mean(f1)
print "—"*110  

print "Words without synonyms:"
print "-"*100

for word in not_in_wordnet:
    print synonyms(word),word

elapsed_time = time.time() - start_time
mins = elapsed_time/float(60)
a = """Elapsed time: %s seconds
In minutes: %s mins""" % (str(elapsed_time), str(mins))
logging.warning(a)

# %% [markdown]
# ### Sample output

# %%
——————————————————————————————————————————————————————————————————————————————————————————————————————————————
Number of Hits: 31 out of top 1000
Number of words without synonyms: 67
——————————————————————————————————————————————————————————————————————————————————————————————————————————————
Precision	0.0280214404967
Recall		0.0178598869579
F1		0.013965517619
——————————————————————————————————————————————————————————————————————————————————————————————————————————————
Words without synonyms:
----------------------------------------------------------------------------------------------------
[] scotia
[] hong
[] kong
[] angeles
[] los
[] nor
[] themselves
[] 
.......

# %% [markdown]
# ## 3.  HW5.7  <a name="5.7"></a> OPTIONAL: using different vocabulary subsets
# [Back to Table of Contents](#TOC)
#
#
# Repeat HW5 using vocabulary words ranked from 8001,-10,000;  7001,-10,000; 6001,-10,000; 5001,-10,000; 3001,-10,000; and 1001,-10,000;
# Dont forget to report you Cluster configuration.
#
# Generate the following graphs:
# -- vocabulary size (X-Axis) versus CPU time for indexing
# -- vocabulary size (X-Axis) versus number of pairs processed
# -- vocabulary size (X-Axis) versus F1 measure, Precision, Recall

# %% [markdown]
# ### 5.7: Vocabulary subset 8001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 8001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 > similarity5.5

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 7001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 7001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 7000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 7000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 7000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 7000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 6001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 6001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 6000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 6000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 6000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 6000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 5001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 5001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 5000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 5000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 5000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 5000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 4001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 4001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 4000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 4000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 4000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 4000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 3001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 3001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 3000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 3000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 3000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 3000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 2001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 2001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5  \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5 \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 2000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 2000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 2000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 2000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ### 5.7: Vocabulary subset 1001-10000

# %%
# !hdfs dfs -rm -r frequencies5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5
# !python frequencies5_5.py --min_rank 1001 --max_rank 10000 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > frequencies5.5

# !hdfs dfs -rm -r stripes5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python stripes5_5.py --file=frequencies5.5 -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt  \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > stripes5.5

# !hdfs dfs -rm -r index5.5
# !python index5_5.py -r hadoop stripes5.5  \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > index5.5

# !hdfs dfs -rm -r similarity5.5
#!python frequencies5_5.py -r hadoop hdfs:///user/cendylin/filtered-5Grams/ > frequencies5.5'
# !python similarity5_5.py -r hadoop index5.5  \
    --python-bin=./my_env/bin/python \
    --archive="hdfs:///user/nhaas/virtualenv/my_env.zip#my_env" \
    > similarity5.5

# %% [markdown]
# ### Frequencies on Vocab Subset 1000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
#
# ### Stripes on Vocab Subset 1000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Index on Vocab Subset 1000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _
#
# ### Similarity on Vocab Subset 1000-10000 Set Statistics:
#
# #### Time
# * _Run time: - seconds_
#
# * _Run time: - minutes_
#
# #### Input/Output statistics
# * _Bytes Read: - _
#
# * _Bytes Written: - _
#
# #### Cluster Resources
# * _Number of Mappers: - _
#
# * _Number of Reducers: - _
#
# * _CPU time spent: - _

# %%
import json

sortedSims = []
with open("similarity5.5","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        sortedSims.append(lisst)

# %%
# !mkdir sims2
# !head -1000 similarity5.5 > sims2/top1000sims

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %% [markdown]
# ## 3.  HW5.8  <a name="5.8"></a> OPTIONAL: filter stopwords
# [Back to Table of Contents](#TOC)
#
# There is also a corpus of stopwords, that is, high-frequency words like "the", "to" and "also" that we sometimes want to filter out of a document before further processing. Stopwords usually have little lexical content, and their presence in a text fails to distinguish it from other texts. Python's nltk comes with a prebuilt list of stopwords (see below). Using this stopword list filter out these tokens from your analysis and rerun the experiments in 5.5 and disucuss the results of using a stopword list and without using a stopword list.
#
# > from nltk.corpus import stopwords
# >> stopwords.words('english')
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
# 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
# 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
# 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
# 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
# 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
# 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
# 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
# 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
# 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
# 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
# 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %% [markdown]
# ## 3.  HW5.9 <a name="5.9"></a> OPTIONAL
# [Back to Table of Contents](#TOC)
#
# There are many good ways to build our synonym detectors, so for this optional homework,
# measure co-occurrence by (left/right/all) consecutive words only,
# or make stripes according to word co-occurrences with the accompanying
# 2-, 3-, or 4-grams (note here that your output will no longer
# be interpretable as a network) inside of the 5-grams.

# %% [markdown]
# ## 3.  HW5.10 <a name="5.10"></a> OPTIONAL
# [Back to Table of Contents](#TOC)
#
# Once again, benchmark your top 10,000 associations (as in 5.5), this time for your
# results from 5.6. Has your detector improved?
